# %% [markdown]
# # Определение стоимости автомобилей

# %% [markdown]
# Сервис по продаже автомобилей с пробегом «Не бит, не крашен» разрабатывает приложение для привлечения новых клиентов. В нём можно быстро узнать рыночную стоимость своего автомобиля. В вашем распоряжении исторические данные: технические характеристики, комплектации и цены автомобилей. Вам нужно построить модель для определения стоимости.
#
# Заказчику важны:
#
# - качество предсказания;
# - скорость предсказания;
# - время обучения.

# %% [markdown]
# ## Подготовка данных

# %%
# !pip install scikit-learn==1.1.3 -q
# !pip install lightgbm==3.3.3 -q
# !pip install imblearn -q
# !pip install phik -q
# !pip install mlxtend -q

# %%
import os
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import re
import warnings

from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from phik.report import plot_correlation_matrix
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import (
    GridSearchCV, 
    train_test_split, 
    cross_val_score
)
from sklearn.preprocessing import (
    OneHotEncoder,
    OrdinalEncoder, 
    StandardScaler
)
from sklearn.compose import make_column_transformer
from tqdm import tqdm
from sklearn.metrics import mean_squared_error


plt.rcParams["figure.figsize"] = (15, 10)

warnings.filterwarnings("ignore")

RANDOM_STATE = 37
TEST_SIZE = 0.25

# %%
pth1 = '/datasets/autos.csv'

if os.path.exists(pth1):
    df = pd.read_csv(pth1, parse_dates=['DateCrawled', 'DateCreated', 'LastSeen'])
else:
    print('Something is wrong')

# %%
df.head()
# Out:
#           DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 0 2016-03-24 11:52:17    480         NaN              1993  manual      0
# 1 2016-03-24 10:58:45  18300       coupe              2011  manual    190
# 2 2016-03-14 12:52:21   9800         suv              2004    auto    163
# 3 2016-03-17 16:54:04   1500       small              2001  manual     75
# 4 2016-03-31 17:25:20   3600       small              2008  manual     69
#
#    Model  Kilometer  RegistrationMonth  FuelType       Brand Repaired  \
# 0   golf     150000                  0    petrol  volkswagen      NaN
# 1    NaN     125000                  5  gasoline        audi      yes
# 2  grand     125000                  8  gasoline        jeep      NaN
# 3   golf     150000                  6    petrol  volkswagen       no
# 4  fabia      90000                  7  gasoline       skoda       no
#
#   DateCreated  NumberOfPictures  PostalCode            LastSeen
# 0  2016-03-24                 0       70435 2016-04-07 03:16:57
# 1  2016-03-24                 0       66954 2016-04-07 01:46:50
# 2  2016-03-14                 0       90480 2016-04-05 12:47:46
# 3  2016-03-17                 0       91074 2016-03-17 17:40:17
# 4  2016-03-31                 0       60437 2016-04-06 10:17:21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        354369 non-null  datetime64[ns]
#  1   Price              354369 non-null  int64
#  2   VehicleType        316879 non-null  object
#  3   RegistrationYear   354369 non-null  int64
#  4   Gearbox            334536 non-null  object
#  5   Power              354369 non-null  int64
#  6   Model              334664 non-null  object
#  7   Kilometer          354369 non-null  int64
#  8   RegistrationMonth  354369 non-null  int64
#  9   FuelType           321474 non-null  object
#  10  Brand              354369 non-null  object
#  11  Repaired           283215 non-null  object
#  12  DateCreated        354369 non-null  datetime64[ns]
#  13  NumberOfPictures   354369 non-null  int64
#  14  PostalCode         354369 non-null  int64
#  15  LastSeen           354369 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), int64(7), object(6)
# memory usage: 43.3+ MB

# %%
df.isna().sum()
# Out:
# DateCrawled              0
# Price                    0
# VehicleType          37490
# RegistrationYear         0
# Gearbox              19833
# Power                    0
# Model                19705
# Kilometer                0
# RegistrationMonth        0
# FuelType             32895
# Brand                    0
# Repaired             71154
# DateCreated              0
# NumberOfPictures         0
# PostalCode               0
# LastSeen                 0
# dtype: int64

# %%
def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind= 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16, color = 'olive')
            .set_title('Пример' + "\n", fontsize = 22, color = 'Blue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(df)

# %%
df.duplicated().sum()
# Out:
# 4

# %% [markdown]
# **Вывод**: Файл открыты и изучен,у нас в наличии 16 столбцов, один из них целевой признак *price*.Посмотрел на основную информацию, пропуски в 5 столбцах, типы данных соответствуют данным, есть 4 дубликата,есть ненужные столбцы для работы.

# %%
new_columns = []
for col in df.columns:
    new_columns.append(re.sub(r'(?<!^)(?=[A-Z])', '_', col).lower())
df.columns = new_columns
# привел название столбцов в змеиный стиль

# %%
for column in df.columns:
    unique_count = df[column].nunique()
    unique_values = df[column].unique()
    print(f"Столбец '{column}' имеет {unique_count} unique values:")
    print(unique_values)
# посмотрел уникальные значения в столбцах и их количестве
# Out:
# Столбец 'date_crawled' имеет 271174 unique values:
# ['2016-03-24T11:52:17.000000000' '2016-03-24T10:58:45.000000000'
#  '2016-03-14T12:52:21.000000000' ... '2016-03-21T09:50:58.000000000'
#  '2016-03-14T17:48:27.000000000' '2016-03-19T18:57:12.000000000']
# Столбец 'price' имеет 3731 unique values:
# [  480 18300  9800 ... 12395 18429 10985]
# Столбец 'vehicle_type' имеет 8 unique values:
# [nan 'coupe' 'suv' 'small' 'sedan' 'convertible' 'bus' 'wagon' 'other']
# Столбец 'registration_year' имеет 151 unique values:
# [1993 2011 2004 2001 2008 1995 1980 2014 1998 2005 1910 2016 2007 2009
#  2002 2018 1997 1990 2017 1981 2003 1994 1991 1984 2006 1999 2012 2010
#  2000 1992 2013 1996 1985 1989 2015 1982 1976 1983 1973 1111 1969 1971
#  1987 1986 1988 1970 1965 1945 1925 1974 1979 1955 1978 1972 1968 1977
#  1961 1960 1966 1975 1963 1964 5000 1954 1958 1967 1959 9999 1956 3200
#  1000 1941 8888 1500 2200 4100 1962 1929 1957 1940 3000 2066 1949 2019
#  1937 1951 1800 1953 1234 8000 5300 9000 2900 6000 5900 5911 1933 1400
#  1950 4000 1948 1952 1200 8500 1932 1255 3700 3800 4800 1942 7000 1935
#  1936 6500 1923 2290 2500 1930 1001 9450 1944 1943 1934 1938 1688 2800
#  1253 1928 1919 5555 5600 1600 2222 1039 9996 1300 8455 1931 1915 4500
#  1920 1602 7800 9229 1947 1927 7100 8200 1946 7500 3500]
# Столбец 'gearbox' имеет 2 unique values:
# ['manual' 'auto' nan]
# Столбец 'power' имеет 712 unique values:
# [    0   190   163    75    69   102   109    50   125   101   105   140
#    115   131    60   136   160   231    90   118   193    99   113   218
#    122   129    70   306    95    61   177    80   170    55   143    64
#    286   232   150   156    82   155    54   185    87   180    86    84
#    224   235   200   178   265    77   110   144   120   116   184   126
#    204    88   194   305   197   179   250    45   313    41   165    98
#    130   114   211    56   201   213    58   107    83   174   100   220
#     85    73   192    68    66   299    74    52   147    65   310    71
#     97   239   203     5   300   103   258   320    63    81   148    44
#    145   230   280   260   104   188   333   186   117   141    59   132
#    234   158    39    92    51   135    53   209    43   146    67   106
#    166   276   344    72   249   237   245   111   326   279    23   138
#    175    96   226    26    37   301   334   128   133   124    33   219
#    241   167    94   182   196   238  1398   228   112    48   272   139
#   1799    40   240    79   256   360   243   375   252   396   340   108
#    121   345   187   289   222   198   284   450   233   387   152   347
#    172    57   137   212   476   314    30     7    47   173   290   207
#    205   171   750    78    91    89   349   325    76   151   350   953
#     93   142   500   343   199   119   164    16   264   367   208   210
#     46   435  1001   225   127   176   161   603   307   354    35   206
#    771   355   273   223   255   123   154   149  7515  1400   268   620
#    169   400   275    34     2   242  1779   285   162   328  1753   329
#    134   420   247   168 10317   215    18   330   283    62    10   214
#    183   254    15   321   322   315   952   600   181   426   599   379
#    999    22   157    42   195   553     4   309   507   381   271   440
#    189   401  1111  2729    21   236  1240  1704   521     1  1900   270
#     24   159   292   808   515  1200   303    29    38  1993    14   216
#    610   504    49   267   331   363   261   385  1011   253   696 10520
#    376   227   311    27   217    20  1999    11  1056    25   394    12
#    298   296  1659   294   551  6920   246    17  1800  1625   368   390
#    221  1367   259   606   327  2017  1597   266   374   392     9   405
#     13   262   601   430   295     8   411   900   541  7512   382 10218
#   7544  1102   287    19   751   297  1090   457   282   602   388     6
#   1000  5411   335  1360   202  3750   805  1062  1024 11530   364  1796
#   5000   269   460  1002   288  1780 12012 17932   316  2005  1399   191
#    278  1300   380   257   449  1256   153  1653   520   560   281 12510
#      3  1500   386    32  1202  2016  1436  1405   671   274  1288  1055
#  10912 15016  6226  1115   277  1105   341  1223  2340  8404  1968   338
#    445  1920   370   517  4400 10710 10522  9010   431  1164 11509   371
#   1501   428 11635    36   304   348  1703  1910  1995   579 10000   580
#    408    31  1005   358  1403   489  5575 19211   585   960   365   353
#    490   352  1801   346   550  3199   800  7508  1312   357  1937   950
#   4700  1600  3454 19208   251   850   337   700  8011  2331  2789   487
#    519  2461  6006  3500  5815  6018  1781  1503   612  1596   229  1506
#   5809 15020  5867  2172  1598 17410  1363   584  1054   851  1339   318
#    510   525  1700    28  1151   685  6011   317   703  1771 15001   514
#    362   332   324  6045   530   425   308  6010   475   903   640  2000
#    248   651  2799 17011   505  1103  1521   351 16051   398  9000  1998
#  10311   409  1230 17019 12684  8259  1895   901  1317   871   909  2201
#   1595   776 17700 11011  1199   459  1162  1120 15033  1896   339   361
#    574  6512   454   650 13616   604   607 16312  1082   336 20000   416
#    678  6012  1401  1021  1870 13636  1250  9710   323  1158  2009   902
#   6062  1275   572   244   399  1016   743  1221  2402 16011  1362   544
#    645   907   702 12512  1986  1003  1432  9013  9011   442  1017  1394
#  15017 10910  1992   540  2018 11025  1433  1701  2792  1502  1239  1390
#  14009  1160  1351 11111  1783  9007   923  1149   754  1988   402  2004
#   5420  1793  1324   356  7511  1299   293 19312  1079  1689   998  1100
#   9012  1933   508 16311   682  1252  1922  7529   732  2389  2200  1707
#   1416  8500  1012   485  3000 10110   421  4507  1631  7518   377  1004
#   2007  2598  1548  1241]
# Столбец 'model' имеет 250 unique values:
# ['golf' nan 'grand' 'fabia' '3er' '2_reihe' 'other' 'c_max' '3_reihe'
#  'passat' 'navara' 'ka' 'polo' 'twingo' 'a_klasse' 'scirocco' '5er'
#  'meriva' 'arosa' 'c4' 'civic' 'transporter' 'punto' 'e_klasse' 'clio'
#  'kadett' 'kangoo' 'corsa' 'one' 'fortwo' '1er' 'b_klasse' 'signum'
#  'astra' 'a8' 'jetta' 'fiesta' 'c_klasse' 'micra' 'vito' 'sprinter' '156'
#  'escort' 'forester' 'xc_reihe' 'scenic' 'a4' 'a1' 'insignia' 'combo'
#  'focus' 'tt' 'a6' 'jazz' 'omega' 'slk' '7er' '80' '147' '100' 'z_reihe'
#  'sportage' 'sorento' 'v40' 'ibiza' 'mustang' 'eos' 'touran' 'getz' 'a3'
#  'almera' 'megane' 'lupo' 'r19' 'zafira' 'caddy' 'mondeo' 'cordoba' 'colt'
#  'impreza' 'vectra' 'berlingo' 'tiguan' 'i_reihe' 'espace' 'sharan'
#  '6_reihe' 'panda' 'up' 'seicento' 'ceed' '5_reihe' 'yeti' 'octavia' 'mii'
#  'rx_reihe' '6er' 'modus' 'fox' 'matiz' 'beetle' 'c1' 'rio' 'touareg'
#  'logan' 'spider' 'cuore' 's_max' 'a2' 'galaxy' 'c3' 'viano' 's_klasse'
#  '1_reihe' 'avensis' 'roomster' 'sl' 'kaefer' 'santa' 'cooper' 'leon'
#  '4_reihe' 'a5' '500' 'laguna' 'ptcruiser' 'clk' 'primera' 'x_reihe'
#  'exeo' '159' 'transit' 'juke' 'qashqai' 'carisma' 'accord' 'corolla'
#  'lanos' 'phaeton' 'verso' 'swift' 'rav' 'picanto' 'boxster' 'kalos'
#  'superb' 'stilo' 'alhambra' 'mx_reihe' 'roadster' 'ypsilon' 'cayenne'
#  'galant' 'justy' '90' 'sirion' 'crossfire' 'agila' 'duster' 'cr_reihe'
#  'v50' 'c_reihe' 'v_klasse' 'm_klasse' 'yaris' 'c5' 'aygo' 'cc' 'carnival'
#  'fusion' '911' 'bora' 'forfour' 'm_reihe' 'cl' 'tigra' '300c' 'spark'
#  'v70' 'kuga' 'x_type' 'ducato' 's_type' 'x_trail' 'toledo' 'altea'
#  'voyager' 'calibra' 'bravo' 'antara' 'tucson' 'citigo' 'jimny' 'wrangler'
#  'lybra' 'q7' 'lancer' 'captiva' 'c2' 'discovery' 'freelander' 'sandero'
#  'note' '900' 'cherokee' 'clubman' 'samara' 'defender' '601' 'cx_reihe'
#  'legacy' 'pajero' 'auris' 'niva' 's60' 'nubira' 'vivaro' 'g_klasse'
#  'lodgy' '850' 'range_rover' 'q3' 'serie_2' 'glk' 'charade' 'croma'
#  'outlander' 'doblo' 'musa' 'move' '9000' 'v60' '145' 'aveo' '200' 'b_max'
#  'range_rover_sport' 'terios' 'rangerover' 'q5' 'range_rover_evoque'
#  'materia' 'delta' 'gl' 'kalina' 'amarok' 'elefantino' 'i3' 'kappa'
#  'serie_3' 'serie_1']
# Столбец 'kilometer' имеет 13 unique values:
# [150000 125000  90000  40000  30000  70000   5000 100000  60000  20000
#   80000  50000  10000]
# Столбец 'registration_month' имеет 13 unique values:
# [ 0  5  8  6  7 10 12 11  2  3  1  4  9]
# Столбец 'fuel_type' имеет 7 unique values:
# ['petrol' 'gasoline' nan 'lpg' 'other' 'hybrid' 'cng' 'electric']
# Столбец 'brand' имеет 40 unique values:
# ['volkswagen' 'audi' 'jeep' 'skoda' 'bmw' 'peugeot' 'ford' 'mazda'
#  'nissan' 'renault' 'mercedes_benz' 'opel' 'seat' 'citroen' 'honda' 'fiat'
#  'mini' 'smart' 'hyundai' 'sonstige_autos' 'alfa_romeo' 'subaru' 'volvo'
#  'mitsubishi' 'kia' 'suzuki' 'lancia' 'toyota' 'chevrolet' 'dacia'
#  'daihatsu' 'trabant' 'saab' 'chrysler' 'jaguar' 'daewoo' 'porsche'
#  'rover' 'land_rover' 'lada']
# Столбец 'repaired' имеет 2 unique values:
# [nan 'yes' 'no']
# Столбец 'date_created' имеет 109 unique values:
# ['2016-03-24T00:00:00.000000000' '2016-03-14T00:00:00.000000000'
#  '2016-03-17T00:00:00.000000000' '2016-03-31T00:00:00.000000000'
#  '2016-04-04T00:00:00.000000000' '2016-04-01T00:00:00.000000000'
#  '2016-03-21T00:00:00.000000000' '2016-03-26T00:00:00.000000000'
#  '2016-04-07T00:00:00.000000000' '2016-03-15T00:00:00.000000000'
#  '2016-03-11T00:00:00.000000000' '2016-03-20T00:00:00.000000000'
#  '2016-03-23T00:00:00.000000000' '2016-03-27T00:00:00.000000000'
#  '2016-03-12T00:00:00.000000000' '2016-03-13T00:00:00.000000000'
#  '2016-03-18T00:00:00.000000000' '2016-03-10T00:00:00.000000000'
#  '2016-03-07T00:00:00.000000000' '2016-03-09T00:00:00.000000000'
#  '2016-03-08T00:00:00.000000000' '2016-04-03T00:00:00.000000000'
#  '2016-03-29T00:00:00.000000000' '2016-03-25T00:00:00.000000000'
#  '2016-03-28T00:00:00.000000000' '2016-03-30T00:00:00.000000000'
#  '2016-03-22T00:00:00.000000000' '2016-02-09T00:00:00.000000000'
#  '2016-03-05T00:00:00.000000000' '2016-04-02T00:00:00.000000000'
#  '2016-03-16T00:00:00.000000000' '2016-03-19T00:00:00.000000000'
#  '2016-04-05T00:00:00.000000000' '2016-03-06T00:00:00.000000000'
#  '2016-02-12T00:00:00.000000000' '2016-03-03T00:00:00.000000000'
#  '2016-03-01T00:00:00.000000000' '2016-03-04T00:00:00.000000000'
#  '2016-04-06T00:00:00.000000000' '2016-02-15T00:00:00.000000000'
#  '2016-02-24T00:00:00.000000000' '2016-02-27T00:00:00.000000000'
#  '2015-03-20T00:00:00.000000000' '2016-02-28T00:00:00.000000000'
#  '2016-02-17T00:00:00.000000000' '2016-01-27T00:00:00.000000000'
#  '2016-02-20T00:00:00.000000000' '2016-02-29T00:00:00.000000000'
#  '2016-02-10T00:00:00.000000000' '2016-02-23T00:00:00.000000000'
#  '2016-02-21T00:00:00.000000000' '2015-11-02T00:00:00.000000000'
#  '2016-02-19T00:00:00.000000000' '2016-02-26T00:00:00.000000000'
#  '2016-02-11T00:00:00.000000000' '2016-01-10T00:00:00.000000000'
#  '2016-02-06T00:00:00.000000000' '2016-02-18T00:00:00.000000000'
#  '2016-01-29T00:00:00.000000000' '2016-03-02T00:00:00.000000000'
#  '2015-12-06T00:00:00.000000000' '2016-01-24T00:00:00.000000000'
#  '2016-01-30T00:00:00.000000000' '2016-02-02T00:00:00.000000000'
#  '2016-02-16T00:00:00.000000000' '2016-02-13T00:00:00.000000000'
#  '2016-02-05T00:00:00.000000000' '2016-02-22T00:00:00.000000000'
#  '2015-11-17T00:00:00.000000000' '2014-03-10T00:00:00.000000000'
#  '2016-02-07T00:00:00.000000000' '2016-01-23T00:00:00.000000000'
#  '2016-02-25T00:00:00.000000000' '2016-02-14T00:00:00.000000000'
#  '2016-01-02T00:00:00.000000000' '2015-09-04T00:00:00.000000000'
#  '2015-11-12T00:00:00.000000000' '2015-12-27T00:00:00.000000000'
#  '2015-11-24T00:00:00.000000000' '2016-01-20T00:00:00.000000000'
#  '2016-02-03T00:00:00.000000000' '2015-12-05T00:00:00.000000000'
#  '2015-08-07T00:00:00.000000000' '2016-01-28T00:00:00.000000000'
#  '2016-01-31T00:00:00.000000000' '2016-02-08T00:00:00.000000000'
#  '2016-01-07T00:00:00.000000000' '2016-01-22T00:00:00.000000000'
#  '2016-01-18T00:00:00.000000000' '2016-01-08T00:00:00.000000000'
#  '2015-11-23T00:00:00.000000000' '2016-01-13T00:00:00.000000000'
#  '2016-01-17T00:00:00.000000000' '2016-01-15T00:00:00.000000000'
#  '2015-11-08T00:00:00.000000000' '2016-01-26T00:00:00.000000000'
#  '2016-02-04T00:00:00.000000000' '2016-01-25T00:00:00.000000000'
#  '2016-01-16T00:00:00.000000000' '2015-08-10T00:00:00.000000000'
#  '2016-01-03T00:00:00.000000000' '2016-01-19T00:00:00.000000000'
#  '2015-12-30T00:00:00.000000000' '2016-02-01T00:00:00.000000000'
#  '2015-12-17T00:00:00.000000000' '2015-11-10T00:00:00.000000000'
#  '2016-01-06T00:00:00.000000000' '2015-09-09T00:00:00.000000000'
#  '2015-06-18T00:00:00.000000000']
# Столбец 'number_of_pictures' имеет 1 unique values:
# [0]
# Столбец 'postal_code' имеет 8143 unique values:
# [70435 66954 90480 ... 38528 38325 31096]
# Столбец 'last_seen' имеет 179150 unique values:
# ['2016-04-07T03:16:57.000000000' '2016-04-07T01:46:50.000000000'
#  '2016-04-05T12:47:46.000000000' ... '2016-03-19T20:44:43.000000000'
#  '2016-03-29T10:17:23.000000000' '2016-03-21T10:42:49.000000000']

# %%
df.describe().T
# посмотрел описательную статистику в таблице
# Out:
#                        count           mean           std     min       25%  \
# price               354369.0    4416.656776   4514.158514     0.0    1050.0
# registration_year   354369.0    2004.234448     90.227958  1000.0    1999.0
# power               354369.0     110.094337    189.850405     0.0      69.0
# kilometer           354369.0  128211.172535  37905.341530  5000.0  125000.0
# registration_month  354369.0       5.714645      3.726421     0.0       3.0
# number_of_pictures  354369.0       0.000000      0.000000     0.0       0.0
# postal_code         354369.0   50508.689087  25783.096248  1067.0   30165.0
#
#                          50%       75%       max
# price                 2700.0    6400.0   20000.0
# registration_year     2003.0    2008.0    9999.0
# power                  105.0     143.0   20000.0
# kilometer           150000.0  150000.0  150000.0
# registration_month       6.0       9.0      12.0
# number_of_pictures       0.0       0.0       0.0
# postal_code          49413.0   71083.0   99998.0

# %%
df.drop(columns=['date_crawled', 'number_of_pictures', 'postal_code', 
                 'last_seen', 'registration_month', 'date_crawled'], axis=1, inplace=True)
# удалил ненужные для обучения столбцы

# %%
df.duplicated().sum()
# Out:
# 13372

# %%
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)
# удалил дубликаты и обновил индексы

# %% [markdown]
# **Вывод:** Удалил дубликаты,привел название столбцов в змеиный стиль, посмотрел описательную статистику в таблице,удалил ненужные для обучения столбцы 'date_crawled', 'number_of_pictures', 'postal_code', 'last_seen', 'registration_month', 'date_crawled'.

# %%
df.price.hist(bins = 150);

# %%
df.boxplot(column=['price'], grid=True, vert=False)
plt.title('Диаграмма размаха цен', size=25);
plt.show()

# %%
df.price.quantile([.05, 0.95])
# посмотрел 0,05 и 0,95 квантиль в столбце price
# Out:
# 0.05      200.0
# 0.95    14600.0
# Name: price, dtype: float64

# %%
1 - df.query('200 <= price <= 14600').shape[0] / len(df)
# посчитал процент тех цен,которые будут удалены
# Out:
# 0.09966070082727996

# %%
df = df.query('199 < price < 14601')

# %% [markdown]
# В целевом признаке присутствуют данные,которые не понадобятся для обучения,это слишком низкая цена до 200 и выбросы более 14600,как ориентир были взяты 0,05 и 0,95 квантиль.

# %%
df = df.query('7 < power < 550')
df.loc[df['power'] <= 50, 'power'] = 105
# отфильтровал мощность двигателя и все что ниже 50 прировнял к медианне

# %% [markdown]
# Мощность ниже 7 можно не брать в расчет,так как это не корректные данные,так же как и мощность более 550,посмотрев список марок и моделей выше 550,скорее всего это аномалии и выбросы,мощность ниже 50 скорее всего это тоже ошибка,прировнял их к медианне.

# %%
df = df.query('1980 <= registration_year <= 2016')
# отфильтровал годы регитраций авто

# %%
hist = df.registration_year.hist(bins=50) 
  
plt.title('Гистограмма регистрации авто', fontsize=18) 
plt.xlabel('год', fontsize=16) 
plt.ylabel('количество авто', fontsize=16) 
   
plt.show()

# %% [markdown]
# Годы регистрации до 1980 считаю не нужные для анализа,их не много и для дальнейшей оценки авто не понадабятся.

# %%
df.kilometer.value_counts()
# вывел уникальные значения
# Out:
# 150000    180802
# 125000     28270
# 100000     10927
# 90000       8682
# 80000       7408
# 70000       6253
# 60000       5264
# 50000       4266
# 40000       3247
# 30000       2762
# 5000        2303
# 20000       2263
# 10000        562
# Name: kilometer, dtype: int64

# %%
hist = df.kilometer.hist(bins=50) 
  
plt.title('Гистограмма пробега (км)', fontsize=18) 
plt.xlabel('пробег (км)', fontsize=16) 
plt.ylabel('количество авто', fontsize=16) 
   
plt.show()

# %% [markdown]
# Вывел уникальные значения столбца с пробегом,данные распределены от 5000 до 150000,больше всего автомобилей с пробегом 150000.

# %%
df.brand.value_counts()
# вывел уникальные значения
# Out:
# volkswagen        56811
# opel              29746
# bmw               27712
# mercedes_benz     23461
# audi              21683
# ford              18614
# renault           12986
# peugeot            8767
# fiat               7036
# seat               5351
# skoda              4414
# mazda              4388
# smart              4313
# citroen            3949
# toyota             3748
# nissan             3609
# hyundai            2790
# volvo              2487
# mini               2374
# mitsubishi         2316
# honda              2232
# kia                1851
# suzuki             1825
# alfa_romeo         1803
# chevrolet          1270
# sonstige_autos     1131
# chrysler           1075
# dacia               756
# subaru              577
# daihatsu            576
# jeep                471
# saab                430
# daewoo              382
# porsche             359
# jaguar              355
# lancia              339
# rover               338
# land_rover          337
# trabant             212
# lada                135
# Name: brand, dtype: int64

# %%
df.gearbox.value_counts()
# Out:
# manual    209696
# auto       48489
# Name: gearbox, dtype: int64

# %%
df['gearbox'] = df['gearbox'].fillna('unknown')

df.reset_index(drop= True , inplace= True)
#заменил пропуски на заглушку и  и обновил индексы

# %% [markdown]
# Заменил пропуски в столбце вид коробки передач на заглушку.

# %%
df['repaired'].unique()
# вывел уникальные значения
# Out:
# array([nan, 'no', 'yes'], dtype=object)

# %%
df['repaired'] = df['repaired'].fillna('unknown')

df.reset_index(drop= True , inplace= True)
#заменил пропуски на заглушку и обновил индексы

# %% [markdown]
# Заменил пропуски в столбце *Repaired* на заглушку,скорее всего большинство авто были в ремонте.

# %%
df.isna().sum()
# выввел суммму пропусков в каждом столбце
# Out:
# price                    0
# vehicle_type         10007
# registration_year        0
# gearbox                  0
# power                    0
# model                 9761
# kilometer                0
# fuel_type            14209
# brand                    0
# repaired                 0
# date_created             0
# dtype: int64

# %%
df['model'] = df['model'].fillna('unknown')

df.reset_index(drop= True , inplace= True)
#заменил пропуски на заглушку и обновил индексы

# %% [markdown]
# Заменил пропуски в столбце *model* на заглушку,пропусков много,при удалении будут большие потери данных.

# %%
df['vehicle_type'].unique()
# вывел уникальные значения
# Out:
# array(['suv', 'small', 'sedan', 'convertible', 'bus', 'wagon', nan,
#        'coupe', 'other'], dtype=object)

# %%
df['vehicle_type'].isnull().sum()
# вывел сумму пропусков в столбце
# Out:
# 10007

# %%
df['vehicle_type'] = df['vehicle_type'].fillna('unknown')

# %% [markdown]
# Заменил пропуски в столбце *vehicle_type* на значение заглушку 'unknown',пропусков много,при удалении будут большие потери данных.

# %%
df['fuel_type'].isnull().sum()
# Out:
# 14209

# %%
df['fuel_type'].unique()
# Out:
# array(['gasoline', 'petrol', nan, 'lpg', 'other', 'hybrid', 'cng',
#        'electric'], dtype=object)

# %%
df['fuel_type'] = df['fuel_type']. replace ('gasoline', 'petrol')

# %%
df['fuel_type'] = df['fuel_type'].fillna('unknown')

# %% [markdown]
# Заменил пропуски в столбце *fuel_type* на значение заглушку 'unknown',пропусков много,при удалении будут большие потери данных.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263009 entries, 0 to 263008
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   price              263009 non-null  int64
#  1   vehicle_type       263009 non-null  object
#  2   registration_year  263009 non-null  int64
#  3   gearbox            263009 non-null  object
#  4   power              263009 non-null  int64
#  5   model              263009 non-null  object
#  6   kilometer          263009 non-null  int64
#  7   fuel_type          263009 non-null  object
#  8   brand              263009 non-null  object
#  9   repaired           263009 non-null  object
#  10  date_created       263009 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(6)
# memory usage: 22.1+ MB

# %%
df_phik = df
interval_cols = ['price', 'registration_year', 'power', 'kilometer', 'registration_month']

phik_overview = df_phik.phik_matrix(interval_cols=interval_cols)

plot_correlation_matrix(
    phik_overview.values,
    x_labels=phik_overview.columns,
    y_labels=phik_overview.index,
    vmin=0, vmax=1, color_map='Greens',
    title=r'Корреляция $\phi_K$',
    fontsize_factor=1.5,
    figsize=(15, 10)
)

# %% [markdown]
# Провел корреляционный анализ, видим зависимость у столбцов и бренд,так же у модели и типа автомобильного кузова,бренда и типа автомобильного кузова,год регистрации автомобиля и цены,моделя и цены,модели с годом регистрации автомобиля и типом коробки передач.

# %% [markdown]
# **Выводы:** Провел корреляцианый анализ,наблюдаю сильную зависимость, при разделении df удалю столбец модель. Так же заменил пропуски в столбцах на заглушки,не стал удалять,так как процент пропусков в каждом столбе большой.

# %% [markdown]
# ## Обучение моделей

# %%
features = df.drop(['price', 'brand'], axis=1)
target = df['price']

X_train, X_test, y_train, y_test = train_test_split(features, target, 
                                                    test_size=TEST_SIZE, random_state=RANDOM_STATE)

# %%
for i in [X_train, X_test, y_train, y_test]:
    print(i.shape)
# Out:
# (197256, 9)
# (65753, 9)
# (197256,)
# (65753,)

# %%
ohe_columns = ['vehicle_type', 'gearbox', 'fuel_type', 'kilometer', 'repaired']

ord_columns = ['model']

num_columns = ['registration_year', 'power']

# %%
ohe_encoder = OneHotEncoder(sparse=False, drop='first')
X_train_ohe = ohe_encoder.fit_transform(X_train[ohe_columns])
X_test_ohe = ohe_encoder.transform(X_test[ohe_columns])
ohe_encoder_col_names = ohe_encoder.get_feature_names_out()

ord_encoder = OrdinalEncoder()
X_train_ord = ord_encoder.fit_transform(X_train[ord_columns])
X_test_ord = ord_encoder.transform(X_test[ord_columns])
ord_encoder_col_names = ord_encoder.get_feature_names_out()

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train[num_columns])
X_test_scaled = scaler.transform(X_test[num_columns])

X_train_ohe = pd.DataFrame(X_train_ohe, columns=ohe_encoder_col_names)
X_test_ohe = pd.DataFrame(X_test_ohe, columns=ohe_encoder_col_names)

X_train_ord = pd.DataFrame(X_train_ord, columns=ord_encoder_col_names)
X_test_ord = pd.DataFrame(X_test_ord, columns=ord_encoder_col_names)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=num_columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=num_columns)

X_train_total = pd.concat([X_train_ohe, X_train_ord, X_train_scaled], axis=1)

X_test_total = pd.concat([X_test_ohe, X_test_ord, X_test_scaled], axis=1)

# %%
for i in [X_train_total, X_test_total, y_train, y_test]:
    print(i.shape)
# Out:
# (197256, 33)
# (65753, 33)
# (197256,)
# (65753,)

# %% [markdown]
# Разделил данные на тестовые и тренировочные, подготовил данные для кодировки и стандартизации,проверил разделении,все соответствует.

# %% [markdown]
# ### Обучение LinearRegression

# %%
import time

# %%
start = time.time()

model_lr = LinearRegression() 
score_lr = cross_val_score(model_lr, X_train_total, y_train, scoring='neg_mean_squared_error', cv=5)
score_lr = round(np.mean(-score_lr)**0.5, 2)
print(f"Среднее значение RMSE: {score_lr:.2f}")

lr_search_time = time.time() - start
print(f'Search time:{round(lr_search_time, 2)}')
# Out:
# Среднее значение RMSE: 2208.98
# Search time:5.57

# %%
# %%time
 
model_lr.fit(X_train_total, y_train)
# Out:
# CPU times: user 694 ms, sys: 393 ms, total: 1.09 s
# Wall time: 1.09 s
# LinearRegression()

# %%
# %%time

predict_lr = model_lr.predict(X_train_total)
# Out:
# CPU times: user 33.5 ms, sys: 25 ms, total: 58.5 ms
# Wall time: 85.3 ms

# %% [markdown]
# Обучил линейную регрессию на закодированных данных,вывел время на данные операции и cреднее значение RMSE: 2208.98

# %% [markdown]
# ### Обучение  CatBoostRegressor

# %%
start = time.time()

model_cbr = CatBoostRegressor(loss_function='RMSE', random_state=RANDOM_STATE, learning_rate=.5, iterations=50, 
                              cat_features=['vehicle_type', 'fuel_type', 'model', 'gearbox', 'kilometer', 'repaired']) 
score_cbr = cross_val_score(model_cbr, X_train, y_train, scoring='neg_mean_squared_error', cv=5)
score_cbr = round(np.mean(-score_cbr)**0.5, 2)
print(f"Среднее значение RMSE: {score_cbr:.2f}")

cbr_search_time = time.time() - start
print(f'Search time:{round(cbr_search_time, 2)}')
# Out:
# 0:	learn: 2568.5955162	total: 137ms	remaining: 6.69s
# 1:	learn: 2088.7456887	total: 235ms	remaining: 5.64s
# 2:	learn: 1895.5430903	total: 314ms	remaining: 4.92s
# 3:	learn: 1780.1383235	total: 372ms	remaining: 4.28s
# 4:	learn: 1714.7093042	total: 428ms	remaining: 3.85s
# 5:	learn: 1679.2629425	total: 486ms	remaining: 3.56s
# 6:	learn: 1659.1581500	total: 545ms	remaining: 3.35s
# 7:	learn: 1622.0390974	total: 605ms	remaining: 3.17s
# 8:	learn: 1603.1711348	total: 668ms	remaining: 3.04s
# 9:	learn: 1588.8072607	total: 735ms	remaining: 2.94s
# 10:	learn: 1577.3456269	total: 814ms	remaining: 2.88s
# 11:	learn: 1567.6339269	total: 876ms	remaining: 2.77s
# 12:	learn: 1558.2974633	total: 944ms	remaining: 2.69s
# 13:	learn: 1549.3556106	total: 1s	remaining: 2.58s
# 14:	learn: 1540.0810444	total: 1.07s	remaining: 2.49s
# 15:	learn: 1533.4293805	total: 1.14s	remaining: 2.42s
# 16:	learn: 1527.9417388	total: 1.22s	remaining: 2.36s
# 17:	learn: 1523.4047296	total: 1.27s	remaining: 2.26s
# 18:	learn: 1517.8089332	total: 1.33s	remaining: 2.17s
# 19:	learn: 1514.7205901	total: 1.41s	remaining: 2.11s
# 20:	learn: 1509.6857596	total: 1.48s	remaining: 2.04s
# 21:	learn: 1505.8872751	total: 1.54s	remaining: 1.96s
# 22:	learn: 1500.8685573	total: 1.6s	remaining: 1.88s
# 23:	learn: 1497.2574110	total: 1.67s	remaining: 1.81s
# 24:	learn: 1494.6039890	total: 1.73s	remaining: 1.73s
# 25:	learn: 1490.4550016	total: 1.8s	remaining: 1.66s
# 26:	learn: 1486.9317004	total: 1.87s	remaining: 1.59s
# 27:	learn: 1483.6967434	total: 1.92s	remaining: 1.51s
# 28:	learn: 1480.7944882	total: 1.99s	remaining: 1.44s
# 29:	learn: 1478.1242207	total: 2.05s	remaining: 1.36s
# 30:	learn: 1475.7209099	total: 2.1s	remaining: 1.29s
# 31:	learn: 1473.3237864	total: 2.17s	remaining: 1.22s
# 32:	learn: 1469.4344869	total: 2.23s	remaining: 1.15s
# 33:	learn: 1466.9581313	total: 2.29s	remaining: 1.08s
# 34:	learn: 1465.5009357	total: 2.35s	remaining: 1.01s
# 35:	learn: 1463.9312391	total: 2.41s	remaining: 938ms
# 36:	learn: 1460.5855384	total: 2.48s	remaining: 870ms
# 37:	learn: 1458.6215995	total: 2.53s	remaining: 800ms
# 38:	learn: 1457.0091355	total: 2.6s	remaining: 732ms
# 39:	learn: 1455.6622440	total: 2.67s	remaining: 667ms
# 40:	learn: 1453.4805404	total: 2.73s	remaining: 600ms
# 41:	learn: 1451.8128757	total: 2.8s	remaining: 533ms
# 42:	learn: 1449.9766146	total: 2.87s	remaining: 467ms
# 43:	learn: 1449.0200301	total: 2.95s	remaining: 402ms
# 44:	learn: 1448.5482684	total: 3.03s	remaining: 336ms
# 45:	learn: 1446.0080019	total: 3.09s	remaining: 269ms
# 46:	learn: 1444.2377696	total: 3.17s	remaining: 202ms
# 47:	learn: 1444.0570497	total: 3.23s	remaining: 135ms
# 48:	learn: 1442.1928786	total: 3.29s	remaining: 67.2ms
# 49:	learn: 1439.8515035	total: 3.35s	remaining: 0us
# 0:	learn: 2597.2262464	total: 82.6ms	remaining: 4.05s
# 1:	learn: 2106.7089700	total: 166ms	remaining: 3.98s
# 2:	learn: 1905.2195755	total: 236ms	remaining: 3.7s
# 3:	learn: 1783.4718290	total: 334ms	remaining: 3.84s
# 4:	learn: 1715.6372632	total: 402ms	remaining: 3.62s
# 5:	learn: 1688.5303392	total: 465ms	remaining: 3.41s
# 6:	learn: 1637.0882214	total: 554ms	remaining: 3.4s
# 7:	learn: 1610.9883065	total: 622ms	remaining: 3.27s
# 8:	learn: 1598.5115153	total: 689ms	remaining: 3.14s
# 9:	learn: 1581.5635420	total: 751ms	remaining: 3s
# 10:	learn: 1570.4225950	total: 817ms	remaining: 2.9s
# 11:	learn: 1560.7977674	total: 885ms	remaining: 2.8s
# 12:	learn: 1551.7289796	total: 954ms	remaining: 2.71s
# 13:	learn: 1548.1507472	total: 1.02s	remaining: 2.63s
# 14:	learn: 1543.4837073	total: 1.08s	remaining: 2.53s
# 15:	learn: 1534.6151155	total: 1.15s	remaining: 2.45s
# 16:	learn: 1525.0389103	total: 1.22s	remaining: 2.37s
# 17:	learn: 1519.0734767	total: 1.28s	remaining: 2.28s
# 18:	learn: 1512.5685992	total: 1.35s	remaining: 2.2s
# 19:	learn: 1509.3111286	total: 1.41s	remaining: 2.11s
# 20:	learn: 1505.1135508	total: 1.47s	remaining: 2.03s
# 21:	learn: 1501.1729111	total: 1.53s	remaining: 1.95s
# 22:	learn: 1497.9342901	total: 1.59s	remaining: 1.87s
# 23:	learn: 1493.5603174	total: 1.66s	remaining: 1.79s
# 24:	learn: 1490.1760725	total: 1.73s	remaining: 1.73s
# 25:	learn: 1487.6929734	total: 1.8s	remaining: 1.66s
# 26:	learn: 1485.1120721	total: 1.87s	remaining: 1.6s
# 27:	learn: 1481.5956427	total: 1.95s	remaining: 1.53s
# 28:	learn: 1479.3675995	total: 2.02s	remaining: 1.47s
# 29:	learn: 1477.2401361	total: 2.09s	remaining: 1.39s
# 30:	learn: 1473.5456108	total: 2.15s	remaining: 1.32s
# 31:	learn: 1471.8606877	total: 2.23s	remaining: 1.25s
# 32:	learn: 1469.9527740	total: 2.29s	remaining: 1.18s
# 33:	learn: 1466.3945750	total: 2.37s	remaining: 1.11s
# 34:	learn: 1464.5274045	total: 2.45s	remaining: 1.05s
# 35:	learn: 1462.0000201	total: 2.52s	remaining: 979ms
# 36:	learn: 1460.1635553	total: 2.58s	remaining: 905ms
# 37:	learn: 1458.3393618	total: 2.64s	remaining: 835ms
# 38:	learn: 1456.4775141	total: 2.71s	remaining: 764ms
# 39:	learn: 1454.2265902	total: 2.76s	remaining: 691ms
# 40:	learn: 1453.3757831	total: 2.83s	remaining: 621ms
# 41:	learn: 1450.7334786	total: 2.9s	remaining: 552ms
# 42:	learn: 1449.6523683	total: 2.96s	remaining: 482ms
# 43:	learn: 1448.2848740	total: 3.03s	remaining: 413ms
# 44:	learn: 1446.7492182	total: 3.1s	remaining: 344ms
# 45:	learn: 1445.0024840	total: 3.16s	remaining: 275ms
# 46:	learn: 1444.9437054	total: 3.23s	remaining: 206ms
# 47:	learn: 1443.5823587	total: 3.3s	remaining: 137ms
# 48:	learn: 1440.8391805	total: 3.36s	remaining: 68.7ms
# 49:	learn: 1438.2617220	total: 3.44s	remaining: 0us
# 0:	learn: 2591.4789428	total: 74.7ms	remaining: 3.66s
# 1:	learn: 2100.6240973	total: 165ms	remaining: 3.96s
# 2:	learn: 1900.4100840	total: 235ms	remaining: 3.69s
# 3:	learn: 1781.5555286	total: 305ms	remaining: 3.5s
# 4:	learn: 1710.8750753	total: 363ms	remaining: 3.27s
# 5:	learn: 1675.5497584	total: 427ms	remaining: 3.13s
# 6:	learn: 1652.4661419	total: 502ms	remaining: 3.08s
# 7:	learn: 1623.2811251	total: 572ms	remaining: 3s
# 8:	learn: 1600.0356776	total: 634ms	remaining: 2.89s
# 9:	learn: 1584.4509834	total: 701ms	remaining: 2.8s
# 10:	learn: 1572.2501328	total: 769ms	remaining: 2.72s
# 11:	learn: 1560.9063483	total: 828ms	remaining: 2.62s
# 12:	learn: 1549.2524574	total: 899ms	remaining: 2.56s
# 13:	learn: 1542.3164650	total: 965ms	remaining: 2.48s
# 14:	learn: 1538.9872778	total: 1.02s	remaining: 2.39s
# 15:	learn: 1534.6131820	total: 1.09s	remaining: 2.32s
# 16:	learn: 1529.5082188	total: 1.16s	remaining: 2.26s
# 17:	learn: 1523.6064264	total: 1.23s	remaining: 2.19s
# 18:	learn: 1517.1369816	total: 1.31s	remaining: 2.14s
# 19:	learn: 1509.3942230	total: 1.4s	remaining: 2.1s
# 20:	learn: 1506.1821562	total: 1.48s	remaining: 2.04s
# 21:	learn: 1500.0568162	total: 1.54s	remaining: 1.96s
# 22:	learn: 1495.3688891	total: 1.61s	remaining: 1.89s
# 23:	learn: 1491.8335688	total: 1.68s	remaining: 1.82s
# 24:	learn: 1490.0456288	total: 1.76s	remaining: 1.76s
# 25:	learn: 1487.1591411	total: 1.82s	remaining: 1.68s
# 26:	learn: 1485.1264697	total: 1.89s	remaining: 1.61s
# 27:	learn: 1481.6510216	total: 1.96s	remaining: 1.54s
# 28:	learn: 1478.5858533	total: 2.02s	remaining: 1.46s
# 29:	learn: 1476.5666826	total: 2.09s	remaining: 1.39s
# 30:	learn: 1471.8878430	total: 2.15s	remaining: 1.32s
# 31:	learn: 1470.1344695	total: 2.21s	remaining: 1.24s
# 32:	learn: 1467.3591315	total: 2.28s	remaining: 1.17s
# 33:	learn: 1465.9038761	total: 2.34s	remaining: 1.1s
# 34:	learn: 1462.4263033	total: 2.4s	remaining: 1.03s
# 35:	learn: 1459.7367029	total: 2.47s	remaining: 959ms
# 36:	learn: 1457.9121613	total: 2.53s	remaining: 890ms
# 37:	learn: 1455.6681748	total: 2.59s	remaining: 819ms
# 38:	learn: 1453.6169028	total: 2.66s	remaining: 750ms
# 39:	learn: 1452.4276057	total: 2.72s	remaining: 680ms
# 40:	learn: 1450.9278094	total: 2.78s	remaining: 611ms
# 41:	learn: 1448.3177112	total: 2.85s	remaining: 543ms
# 42:	learn: 1445.9446302	total: 2.91s	remaining: 473ms
# 43:	learn: 1444.2625187	total: 2.97s	remaining: 405ms
# 44:	learn: 1441.9858123	total: 3.04s	remaining: 338ms
# 45:	learn: 1440.5191895	total: 3.1s	remaining: 270ms
# 46:	learn: 1439.5829952	total: 3.19s	remaining: 203ms
# 47:	learn: 1438.6664755	total: 3.27s	remaining: 136ms
# 48:	learn: 1437.9666278	total: 3.34s	remaining: 68.2ms
# 49:	learn: 1437.0363522	total: 3.42s	remaining: 0us
# 0:	learn: 2603.1764200	total: 73.6ms	remaining: 3.61s
# 1:	learn: 2114.5165683	total: 145ms	remaining: 3.49s
# 2:	learn: 1906.5001083	total: 211ms	remaining: 3.31s
# 3:	learn: 1776.2708521	total: 271ms	remaining: 3.12s
# 4:	learn: 1717.6872630	total: 332ms	remaining: 2.99s
# 5:	learn: 1687.7831354	total: 391ms	remaining: 2.87s
# 6:	learn: 1640.5384085	total: 448ms	remaining: 2.75s
# 7:	learn: 1614.6101181	total: 514ms	remaining: 2.7s
# 8:	learn: 1594.4069477	total: 573ms	remaining: 2.61s
# 9:	learn: 1582.5362738	total: 645ms	remaining: 2.58s
# 10:	learn: 1570.5891974	total: 729ms	remaining: 2.58s
# 11:	learn: 1560.4678718	total: 794ms	remaining: 2.52s
# 12:	learn: 1553.4392240	total: 875ms	remaining: 2.49s
# 13:	learn: 1542.3922608	total: 950ms	remaining: 2.44s
# 14:	learn: 1535.6455791	total: 1.01s	remaining: 2.36s
# 15:	learn: 1526.2421387	total: 1.07s	remaining: 2.27s
# 16:	learn: 1522.6370112	total: 1.14s	remaining: 2.21s
# 17:	learn: 1519.1346451	total: 1.2s	remaining: 2.13s
# 18:	learn: 1515.5380783	total: 1.26s	remaining: 2.05s
# 19:	learn: 1511.9698494	total: 1.32s	remaining: 1.98s
# 20:	learn: 1504.0261080	total: 1.38s	remaining: 1.9s
# 21:	learn: 1500.7751732	total: 1.44s	remaining: 1.83s
# 22:	learn: 1497.3614858	total: 1.5s	remaining: 1.76s
# 23:	learn: 1494.2509615	total: 1.55s	remaining: 1.68s
# 24:	learn: 1491.9133144	total: 1.62s	remaining: 1.62s
# 25:	learn: 1488.0487502	total: 1.68s	remaining: 1.55s
# 26:	learn: 1484.5511491	total: 1.74s	remaining: 1.48s
# 27:	learn: 1481.0610633	total: 1.81s	remaining: 1.42s
# 28:	learn: 1478.3903768	total: 1.87s	remaining: 1.35s
# 29:	learn: 1475.7634101	total: 1.93s	remaining: 1.29s
# 30:	learn: 1474.1209004	total: 2s	remaining: 1.22s
# 31:	learn: 1471.7751664	total: 2.06s	remaining: 1.16s
# 32:	learn: 1468.9843448	total: 2.13s	remaining: 1.09s
# 33:	learn: 1466.0525890	total: 2.2s	remaining: 1.04s
# 34:	learn: 1462.8532880	total: 2.27s	remaining: 971ms
# 35:	learn: 1461.0007115	total: 2.33s	remaining: 907ms
# 36:	learn: 1457.8256507	total: 2.39s	remaining: 841ms
# 37:	learn: 1454.5632258	total: 2.46s	remaining: 776ms
# 38:	learn: 1453.0381974	total: 2.52s	remaining: 710ms
# 39:	learn: 1450.4658419	total: 2.58s	remaining: 645ms
# 40:	learn: 1448.2279690	total: 2.65s	remaining: 582ms
# 41:	learn: 1446.1821542	total: 2.71s	remaining: 517ms
# 42:	learn: 1445.1472546	total: 2.78s	remaining: 452ms
# 43:	learn: 1442.7789946	total: 2.84s	remaining: 387ms
# 44:	learn: 1442.0116437	total: 2.9s	remaining: 322ms
# 45:	learn: 1441.4056151	total: 2.96s	remaining: 257ms
# 46:	learn: 1440.0961090	total: 3.02s	remaining: 193ms
# 47:	learn: 1437.9746357	total: 3.08s	remaining: 128ms
# 48:	learn: 1436.9021056	total: 3.13s	remaining: 64ms
# 49:	learn: 1436.5525220	total: 3.2s	remaining: 0us
# 0:	learn: 2594.1488035	total: 73.2ms	remaining: 3.59s
# 1:	learn: 2103.1380762	total: 161ms	remaining: 3.85s
# 2:	learn: 1902.3588094	total: 226ms	remaining: 3.54s
# 3:	learn: 1785.7114363	total: 292ms	remaining: 3.36s
# 4:	learn: 1721.2182514	total: 357ms	remaining: 3.22s
# 5:	learn: 1686.9500239	total: 420ms	remaining: 3.08s
# 6:	learn: 1667.0020052	total: 482ms	remaining: 2.96s
# 7:	learn: 1630.0657032	total: 544ms	remaining: 2.85s
# 8:	learn: 1604.1915855	total: 605ms	remaining: 2.76s
# 9:	learn: 1589.4025691	total: 672ms	remaining: 2.69s
# 10:	learn: 1576.9317439	total: 740ms	remaining: 2.62s
# 11:	learn: 1565.2971981	total: 810ms	remaining: 2.56s
# 12:	learn: 1554.3456843	total: 874ms	remaining: 2.49s
# 13:	learn: 1545.0314975	total: 937ms	remaining: 2.41s
# 14:	learn: 1536.7268837	total: 997ms	remaining: 2.33s
# 15:	learn: 1528.3194989	total: 1.06s	remaining: 2.25s
# 16:	learn: 1523.0329574	total: 1.13s	remaining: 2.19s
# 17:	learn: 1519.3480312	total: 1.19s	remaining: 2.11s
# 18:	learn: 1512.8907586	total: 1.25s	remaining: 2.04s
# 19:	learn: 1508.5518017	total: 1.32s	remaining: 1.97s
# 20:	learn: 1504.6652568	total: 1.38s	remaining: 1.91s
# 21:	learn: 1500.2993940	total: 1.45s	remaining: 1.85s
# 22:	learn: 1497.2826682	total: 1.52s	remaining: 1.79s
# 23:	learn: 1492.4193534	total: 1.59s	remaining: 1.72s
# 24:	learn: 1488.6946705	total: 1.66s	remaining: 1.66s
# 25:	learn: 1486.1595356	total: 1.72s	remaining: 1.59s
# 26:	learn: 1482.5367039	total: 1.8s	remaining: 1.54s
# 27:	learn: 1479.3110449	total: 1.87s	remaining: 1.47s
# 28:	learn: 1476.8206325	total: 1.94s	remaining: 1.4s
# 29:	learn: 1474.1688460	total: 2s	remaining: 1.33s
# 30:	learn: 1471.5506233	total: 2.07s	remaining: 1.27s
# 31:	learn: 1468.7516781	total: 2.13s	remaining: 1.2s
# 32:	learn: 1467.3088638	total: 2.2s	remaining: 1.13s
# 33:	learn: 1465.2911313	total: 2.28s	remaining: 1.07s
# 34:	learn: 1464.0068810	total: 2.34s	remaining: 1s
# 35:	learn: 1461.5000079	total: 2.4s	remaining: 934ms
# 36:	learn: 1458.2731339	total: 2.46s	remaining: 866ms
# 37:	learn: 1456.4784025	total: 2.52s	remaining: 797ms
# 38:	learn: 1454.9171442	total: 2.59s	remaining: 729ms
# 39:	learn: 1452.1618863	total: 2.65s	remaining: 662ms
# 40:	learn: 1450.6530134	total: 2.72s	remaining: 597ms
# 41:	learn: 1449.0246479	total: 2.78s	remaining: 530ms
# 42:	learn: 1447.1643979	total: 2.88s	remaining: 469ms
# 43:	learn: 1445.3281053	total: 2.94s	remaining: 401ms
# 44:	learn: 1443.6812563	total: 3s	remaining: 333ms
# 45:	learn: 1441.7900422	total: 3.06s	remaining: 266ms
# 46:	learn: 1440.1482546	total: 3.11s	remaining: 199ms
# 47:	learn: 1438.7595952	total: 3.18s	remaining: 132ms
# 48:	learn: 1437.8954888	total: 3.23s	remaining: 66ms
# 49:	learn: 1436.7860079	total: 3.29s	remaining: 0us
# Среднее значение RMSE: 1449.44
# Search time:22.63

# %%
# %%time

model_cbr.fit(X_train, y_train)
# Out:
# 0:	learn: 2584.6251760	total: 95.4ms	remaining: 4.67s
# 1:	learn: 2136.1111894	total: 187ms	remaining: 4.49s
# 2:	learn: 1904.7824240	total: 281ms	remaining: 4.4s
# 3:	learn: 1770.8153529	total: 362ms	remaining: 4.17s
# 4:	learn: 1706.7649026	total: 439ms	remaining: 3.95s
# 5:	learn: 1676.1761354	total: 514ms	remaining: 3.77s
# 6:	learn: 1653.1271809	total: 587ms	remaining: 3.61s
# 7:	learn: 1614.1600225	total: 661ms	remaining: 3.47s
# 8:	learn: 1597.8452067	total: 740ms	remaining: 3.37s
# 9:	learn: 1586.9862013	total: 815ms	remaining: 3.26s
# 10:	learn: 1577.2115124	total: 893ms	remaining: 3.17s
# 11:	learn: 1564.3252402	total: 969ms	remaining: 3.07s
# 12:	learn: 1554.9624360	total: 1.05s	remaining: 2.98s
# 13:	learn: 1545.9497254	total: 1.12s	remaining: 2.89s
# 14:	learn: 1539.8828585	total: 1.21s	remaining: 2.82s
# 15:	learn: 1534.0796962	total: 1.28s	remaining: 2.73s
# 16:	learn: 1523.4763330	total: 1.38s	remaining: 2.68s
# 17:	learn: 1517.7562017	total: 1.47s	remaining: 2.61s
# 18:	learn: 1515.2616442	total: 1.54s	remaining: 2.52s
# 19:	learn: 1510.5061437	total: 1.62s	remaining: 2.43s
# 20:	learn: 1505.9566017	total: 1.7s	remaining: 2.34s
# 21:	learn: 1500.4490519	total: 1.77s	remaining: 2.25s
# 22:	learn: 1497.8807603	total: 1.84s	remaining: 2.17s
# 23:	learn: 1494.7608949	total: 1.92s	remaining: 2.08s
# 24:	learn: 1492.3547550	total: 2s	remaining: 2s
# 25:	learn: 1488.7413531	total: 2.08s	remaining: 1.92s
# 26:	learn: 1485.7338853	total: 2.15s	remaining: 1.83s
# 27:	learn: 1483.1231145	total: 2.23s	remaining: 1.75s
# 28:	learn: 1479.3492198	total: 2.31s	remaining: 1.67s
# 29:	learn: 1476.2003633	total: 2.39s	remaining: 1.59s
# 30:	learn: 1474.1203339	total: 2.48s	remaining: 1.52s
# 31:	learn: 1470.6706199	total: 2.57s	remaining: 1.45s
# 32:	learn: 1467.9610947	total: 2.65s	remaining: 1.36s
# 33:	learn: 1466.4312058	total: 2.73s	remaining: 1.29s
# 34:	learn: 1464.5468171	total: 2.81s	remaining: 1.2s
# 35:	learn: 1461.5810350	total: 2.9s	remaining: 1.13s
# 36:	learn: 1458.4911164	total: 2.98s	remaining: 1.05s
# 37:	learn: 1455.0055924	total: 3.06s	remaining: 965ms
# 38:	learn: 1452.9982668	total: 3.14s	remaining: 885ms
# 39:	learn: 1451.3643531	total: 3.22s	remaining: 805ms
# 40:	learn: 1449.9670748	total: 3.3s	remaining: 725ms
# 41:	learn: 1448.2641128	total: 3.38s	remaining: 644ms
# 42:	learn: 1445.2610707	total: 3.46s	remaining: 563ms
# 43:	learn: 1443.8658035	total: 3.54s	remaining: 483ms
# 44:	learn: 1442.3844848	total: 3.62s	remaining: 402ms
# 45:	learn: 1439.5159329	total: 3.7s	remaining: 321ms
# 46:	learn: 1439.3851666	total: 3.77s	remaining: 241ms
# 47:	learn: 1438.5228677	total: 3.85s	remaining: 161ms
# 48:	learn: 1436.9338011	total: 3.94s	remaining: 80.5ms
# 49:	learn: 1435.9282597	total: 4.02s	remaining: 0us
# CPU times: user 4.44 s, sys: 43.1 ms, total: 4.49 s
# Wall time: 4.98 s

# %%
# %%time

predict_cbr = model_cbr.predict(X_train)
# Out:
# CPU times: user 326 ms, sys: 11.6 ms, total: 338 ms
# Wall time: 337 ms

# %% [markdown]
# Обучил CatBoostRegressor,вывел время на данные операции и среднее значение RMSE: 1449.44

# %% [markdown]
# ### обучение CatBoostRegressor GridSearchCV

# %%
start = time.time()

model_cbr_gs = CatBoostRegressor()
parameters = {'depth' : [6,8,10],
              'learning_rate' : [0.01, 0.05, 0.1],
              'iterations'    : [30, 50, 100]
              }

grid_cbr = GridSearchCV(estimator=model_cbr_gs, param_grid = parameters, cv = 5, n_jobs=-1, scoring='neg_mean_squared_error')
grid_cbr.fit(X_train_total, y_train)

gs_search_time = time.time() - start
print(f'Search time:{gs_search_time}')
# Out:
# 0:	learn: 3544.6209765	total: 23ms	remaining: 666ms
# 1:	learn: 3521.7832050	total: 45.5ms	remaining: 638ms
# 2:	learn: 3499.5848716	total: 67.1ms	remaining: 604ms
# 3:	learn: 3477.3192672	total: 87.8ms	remaining: 571ms
# 4:	learn: 3455.5678060	total: 109ms	remaining: 545ms
# 5:	learn: 3434.2583168	total: 130ms	remaining: 521ms
# 6:	learn: 3412.8128401	total: 152ms	remaining: 499ms
# 7:	learn: 3392.0070397	total: 175ms	remaining: 481ms
# 8:	learn: 3371.4921136	total: 198ms	remaining: 462ms
# 9:	learn: 3351.0959766	total: 221ms	remaining: 442ms
# 10:	learn: 3331.2234335	total: 248ms	remaining: 428ms
# 11:	learn: 3310.6473338	total: 271ms	remaining: 406ms
# 12:	learn: 3290.3859076	total: 293ms	remaining: 383ms
# 13:	learn: 3270.8419076	total: 315ms	remaining: 360ms
# 14:	learn: 3251.4708529	total: 338ms	remaining: 338ms
# 15:	learn: 3231.9267823	total: 360ms	remaining: 315ms
# 16:	learn: 3213.4968680	total: 383ms	remaining: 293ms
# 17:	learn: 3194.9667244	total: 414ms	remaining: 276ms
# 18:	learn: 3176.3479736	total: 436ms	remaining: 253ms
# 19:	learn: 3158.4030899	total: 458ms	remaining: 229ms
# 20:	learn: 3140.7420363	total: 478ms	remaining: 205ms
# 21:	learn: 3123.1695043	total: 498ms	remaining: 181ms
# 22:	learn: 3105.6853146	total: 522ms	remaining: 159ms
# 23:	learn: 3088.3406604	total: 543ms	remaining: 136ms
# 24:	learn: 3071.0620302	total: 564ms	remaining: 113ms
# 25:	learn: 3054.1562241	total: 586ms	remaining: 90.2ms
# 26:	learn: 3037.6368964	total: 607ms	remaining: 67.5ms
# 27:	learn: 3021.0203311	total: 629ms	remaining: 45ms
# 28:	learn: 3004.9207527	total: 652ms	remaining: 22.5ms
# 29:	learn: 2988.9735663	total: 675ms	remaining: 0us
# 0:	learn: 3547.2612585	total: 23.1ms	remaining: 671ms
# 1:	learn: 3524.9974871	total: 45.7ms	remaining: 640ms
# 2:	learn: 3503.0170093	total: 69.1ms	remaining: 622ms
# 3:	learn: 3480.9810756	total: 92.2ms	remaining: 599ms
# 4:	learn: 3459.0325616	total: 115ms	remaining: 576ms
# 5:	learn: 3437.6122070	total: 144ms	remaining: 575ms
# 6:	learn: 3416.7358758	total: 169ms	remaining: 557ms
# 7:	learn: 3395.9795566	total: 191ms	remaining: 526ms
# 8:	learn: 3375.4285282	total: 213ms	remaining: 497ms
# 9:	learn: 3355.0339643	total: 234ms	remaining: 469ms
# 10:	learn: 3334.8309878	total: 257ms	remaining: 444ms
# 11:	learn: 3314.1580152	total: 278ms	remaining: 417ms
# 12:	learn: 3293.9097487	total: 299ms	remaining: 391ms
# 13:	learn: 3274.6667933	total: 323ms	remaining: 369ms
# 14:	learn: 3255.6340804	total: 360ms	remaining: 360ms
# 15:	learn: 3236.4326124	total: 381ms	remaining: 333ms
# 16:	learn: 3217.6658592	total: 401ms	remaining: 307ms
# 17:	learn: 3198.6665987	total: 422ms	remaining: 281ms
# 18:	learn: 3180.2317476	total: 443ms	remaining: 256ms
# 19:	learn: 3162.2149166	total: 464ms	remaining: 232ms
# 20:	learn: 3144.3947984	total: 485ms	remaining: 208ms
# 21:	learn: 3126.8578850	total: 505ms	remaining: 184ms
# 22:	learn: 3108.8880594	total: 526ms	remaining: 160ms
# 23:	learn: 3091.6829308	total: 547ms	remaining: 137ms
# 24:	learn: 3074.2222813	total: 567ms	remaining: 113ms
# 25:	learn: 3057.4899731	total: 589ms	remaining: 90.6ms
# 26:	learn: 3040.2757287	total: 610ms	remaining: 67.7ms
# 27:	learn: 3023.6574196	total: 631ms	remaining: 45.1ms
# 28:	learn: 3007.5513167	total: 653ms	remaining: 22.5ms
# 29:	learn: 2991.6937483	total: 674ms	remaining: 0us
# 0:	learn: 3544.9408446	total: 25ms	remaining: 725ms
# 1:	learn: 3522.3269624	total: 45.6ms	remaining: 638ms
# 2:	learn: 3500.3023030	total: 66.5ms	remaining: 598ms
# 3:	learn: 3478.2510655	total: 88.1ms	remaining: 573ms
# 4:	learn: 3456.4463988	total: 110ms	remaining: 552ms
# 5:	learn: 3434.9775173	total: 143ms	remaining: 572ms
# 6:	learn: 3414.0252434	total: 172ms	remaining: 566ms
# 7:	learn: 3393.2576677	total: 194ms	remaining: 534ms
# 8:	learn: 3372.6778635	total: 216ms	remaining: 504ms
# 9:	learn: 3352.2367123	total: 241ms	remaining: 482ms
# 10:	learn: 3332.2959905	total: 274ms	remaining: 473ms
# 11:	learn: 3311.6563455	total: 294ms	remaining: 441ms
# 12:	learn: 3291.3584691	total: 314ms	remaining: 410ms
# 13:	learn: 3272.0532600	total: 334ms	remaining: 382ms
# 14:	learn: 3252.9927142	total: 355ms	remaining: 355ms
# 15:	learn: 3233.3770364	total: 376ms	remaining: 329ms
# 16:	learn: 3214.9359517	total: 398ms	remaining: 304ms
# 17:	learn: 3195.7801262	total: 421ms	remaining: 280ms
# 18:	learn: 3177.2923716	total: 444ms	remaining: 257ms
# 19:	learn: 3158.7758852	total: 466ms	remaining: 233ms
# 20:	learn: 3140.6232161	total: 491ms	remaining: 210ms
# 21:	learn: 3122.7462607	total: 515ms	remaining: 187ms
# 22:	learn: 3105.3065087	total: 544ms	remaining: 166ms
# 23:	learn: 3088.1376664	total: 575ms	remaining: 144ms
# 24:	learn: 3070.6171934	total: 600ms	remaining: 120ms
# 25:	learn: 3054.0085618	total: 626ms	remaining: 96.3ms
# 26:	learn: 3036.8330525	total: 658ms	remaining: 73.1ms
# 27:	learn: 3020.2343829	total: 683ms	remaining: 48.8ms
# 28:	learn: 3004.1673701	total: 704ms	remaining: 24.3ms
# 29:	learn: 2988.1841123	total: 729ms	remaining: 0us
# 0:	learn: 3543.8743780	total: 21.2ms	remaining: 615ms
# 1:	learn: 3521.4337917	total: 42.6ms	remaining: 597ms
# 2:	learn: 3499.4496263	total: 74.6ms	remaining: 672ms
# 3:	learn: 3477.4104912	total: 105ms	remaining: 681ms
# 4:	learn: 3455.3882040	total: 126ms	remaining: 632ms
# 5:	learn: 3434.2911711	total: 156ms	remaining: 624ms
# 6:	learn: 3412.8112634	total: 177ms	remaining: 581ms
# 7:	learn: 3392.1335722	total: 197ms	remaining: 543ms
# 8:	learn: 3371.5611910	total: 220ms	remaining: 512ms
# 9:	learn: 3351.1634203	total: 247ms	remaining: 493ms
# 10:	learn: 3330.9793514	total: 269ms	remaining: 465ms
# 11:	learn: 3310.4045726	total: 293ms	remaining: 439ms
# 12:	learn: 3290.1363930	total: 320ms	remaining: 419ms
# 13:	learn: 3270.8112615	total: 352ms	remaining: 402ms
# 14:	learn: 3251.9185714	total: 372ms	remaining: 372ms
# 15:	learn: 3232.9268199	total: 393ms	remaining: 344ms
# 16:	learn: 3214.2522068	total: 413ms	remaining: 316ms
# 17:	learn: 3195.2795179	total: 443ms	remaining: 295ms
# 18:	learn: 3176.6052170	total: 464ms	remaining: 269ms
# 19:	learn: 3158.0461142	total: 485ms	remaining: 243ms
# 20:	learn: 3139.9392220	total: 506ms	remaining: 217ms
# 21:	learn: 3122.3902570	total: 526ms	remaining: 191ms
# 22:	learn: 3104.4857583	total: 561ms	remaining: 171ms
# 23:	learn: 3087.2257204	total: 582ms	remaining: 146ms
# 24:	learn: 3069.8441272	total: 602ms	remaining: 120ms
# 25:	learn: 3053.2415944	total: 623ms	remaining: 95.9ms
# 26:	learn: 3036.3872703	total: 652ms	remaining: 72.5ms
# 27:	learn: 3019.7805068	total: 674ms	remaining: 48.2ms
# 28:	learn: 3003.6894367	total: 696ms	remaining: 24ms
# 29:	learn: 2987.8351191	total: 717ms	remaining: 0us
# 0:	learn: 3551.1401178	total: 25.8ms	remaining: 749ms
# 1:	learn: 3528.5506364	total: 47.2ms	remaining: 660ms
# 2:	learn: 3506.5218296	total: 68.8ms	remaining: 619ms
# 3:	learn: 3484.3887670	total: 90.1ms	remaining: 586ms
# 4:	learn: 3462.8341182	total: 116ms	remaining: 580ms
# 5:	learn: 3441.1217988	total: 137ms	remaining: 549ms
# 6:	learn: 3420.1368422	total: 159ms	remaining: 521ms
# 7:	learn: 3399.2700851	total: 179ms	remaining: 492ms
# 8:	learn: 3378.6130435	total: 207ms	remaining: 484ms
# 9:	learn: 3357.7574598	total: 229ms	remaining: 459ms
# 10:	learn: 3337.7551200	total: 251ms	remaining: 434ms
# 11:	learn: 3317.3650904	total: 273ms	remaining: 410ms
# 12:	learn: 3297.0475054	total: 301ms	remaining: 394ms
# 13:	learn: 3277.6481866	total: 324ms	remaining: 371ms
# 14:	learn: 3258.1532260	total: 347ms	remaining: 347ms
# 15:	learn: 3239.0963075	total: 369ms	remaining: 323ms
# 16:	learn: 3220.0514066	total: 397ms	remaining: 304ms
# 17:	learn: 3201.0065287	total: 419ms	remaining: 280ms
# 18:	learn: 3182.2922621	total: 442ms	remaining: 256ms
# 19:	learn: 3163.6878056	total: 465ms	remaining: 232ms
# 20:	learn: 3145.8563096	total: 486ms	remaining: 208ms
# 21:	learn: 3128.2940679	total: 509ms	remaining: 185ms
# 22:	learn: 3110.8405737	total: 532ms	remaining: 162ms
# 23:	learn: 3093.6183394	total: 561ms	remaining: 140ms
# 24:	learn: 3076.3956928	total: 589ms	remaining: 118ms
# 25:	learn: 3059.3156187	total: 612ms	remaining: 94.2ms
# 26:	learn: 3042.0911342	total: 635ms	remaining: 70.6ms
# 27:	learn: 3025.4452380	total: 659ms	remaining: 47.1ms
# 28:	learn: 3009.2971695	total: 686ms	remaining: 23.7ms
# 29:	learn: 2993.4531344	total: 717ms	remaining: 0us
# 0:	learn: 3454.9095270	total: 21.8ms	remaining: 633ms
# 1:	learn: 3347.9894700	total: 43.9ms	remaining: 615ms
# 2:	learn: 3249.0484720	total: 65.8ms	remaining: 593ms
# 3:	learn: 3150.9679739	total: 87.3ms	remaining: 568ms
# 4:	learn: 3062.6322324	total: 110ms	remaining: 550ms
# 5:	learn: 2977.4508982	total: 132ms	remaining: 527ms
# 6:	learn: 2902.0643303	total: 154ms	remaining: 507ms
# 7:	learn: 2828.5479472	total: 177ms	remaining: 488ms
# 8:	learn: 2759.0254233	total: 200ms	remaining: 467ms
# 9:	learn: 2691.7380079	total: 223ms	remaining: 445ms
# 10:	learn: 2632.2572171	total: 245ms	remaining: 424ms
# 11:	learn: 2573.8486963	total: 267ms	remaining: 401ms
# 12:	learn: 2518.9843712	total: 289ms	remaining: 378ms
# 13:	learn: 2469.6266013	total: 311ms	remaining: 355ms
# 14:	learn: 2421.8144561	total: 332ms	remaining: 332ms
# 15:	learn: 2378.0837476	total: 354ms	remaining: 310ms
# 16:	learn: 2338.3525777	total: 378ms	remaining: 289ms
# 17:	learn: 2300.8692849	total: 405ms	remaining: 270ms
# 18:	learn: 2262.9888921	total: 428ms	remaining: 248ms
# 19:	learn: 2228.3730399	total: 450ms	remaining: 225ms
# 20:	learn: 2198.0488591	total: 476ms	remaining: 204ms
# 21:	learn: 2169.3013355	total: 499ms	remaining: 182ms
# 22:	learn: 2140.9105311	total: 521ms	remaining: 159ms
# 23:	learn: 2116.5855442	total: 543ms	remaining: 136ms
# 24:	learn: 2091.5856458	total: 570ms	remaining: 114ms
# 25:	learn: 2068.5544734	total: 592ms	remaining: 91.1ms
# 26:	learn: 2047.3615413	total: 614ms	remaining: 68.2ms
# 27:	learn: 2027.8502919	total: 635ms	remaining: 45.4ms
# 28:	learn: 2008.0378937	total: 662ms	remaining: 22.8ms
# 29:	learn: 1990.4607583	total: 683ms	remaining: 0us
# 0:	learn: 3456.1111503	total: 33.4ms	remaining: 968ms
# 1:	learn: 3348.9580717	total: 55.6ms	remaining: 779ms
# 2:	learn: 3250.4834789	total: 78.2ms	remaining: 704ms
# 3:	learn: 3156.2998020	total: 100ms	remaining: 652ms
# 4:	learn: 3067.8464575	total: 141ms	remaining: 704ms
# 5:	learn: 2984.3696482	total: 170ms	remaining: 681ms
# 6:	learn: 2906.8788896	total: 193ms	remaining: 635ms
# 7:	learn: 2833.4635740	total: 223ms	remaining: 612ms
# 8:	learn: 2764.7310885	total: 254ms	remaining: 593ms
# 9:	learn: 2698.1313631	total: 278ms	remaining: 557ms
# 10:	learn: 2639.3245971	total: 301ms	remaining: 519ms
# 11:	learn: 2580.1826890	total: 328ms	remaining: 492ms
# 12:	learn: 2525.8165022	total: 350ms	remaining: 458ms
# 13:	learn: 2476.1786934	total: 372ms	remaining: 426ms
# 14:	learn: 2429.8424893	total: 394ms	remaining: 394ms
# 15:	learn: 2384.4389406	total: 422ms	remaining: 369ms
# 16:	learn: 2344.8462277	total: 445ms	remaining: 340ms
# 17:	learn: 2307.6511463	total: 467ms	remaining: 311ms
# 18:	learn: 2269.4001097	total: 489ms	remaining: 283ms
# 19:	learn: 2235.5160476	total: 523ms	remaining: 261ms
# 20:	learn: 2203.5699437	total: 544ms	remaining: 233ms
# 21:	learn: 2174.3237514	total: 565ms	remaining: 205ms
# 22:	learn: 2145.5437633	total: 586ms	remaining: 178ms
# 23:	learn: 2118.1619346	total: 612ms	remaining: 153ms
# 24:	learn: 2093.0260294	total: 634ms	remaining: 127ms
# 25:	learn: 2070.2647165	total: 656ms	remaining: 101ms
# 26:	learn: 2049.4872902	total: 678ms	remaining: 75.3ms
# 27:	learn: 2029.5489023	total: 706ms	remaining: 50.4ms
# 28:	learn: 2010.7418367	total: 729ms	remaining: 25.1ms
# 29:	learn: 1992.9162202	total: 751ms	remaining: 0us
# 0:	learn: 3455.0994567	total: 21.8ms	remaining: 633ms
# 1:	learn: 3347.4236467	total: 44.9ms	remaining: 629ms
# 2:	learn: 3248.8193223	total: 72.7ms	remaining: 654ms
# 3:	learn: 3155.4728480	total: 105ms	remaining: 680ms
# 4:	learn: 3063.0169821	total: 130ms	remaining: 650ms
# 5:	learn: 2976.7562035	total: 159ms	remaining: 636ms
# 6:	learn: 2899.2424058	total: 186ms	remaining: 610ms
# 7:	learn: 2825.4617963	total: 209ms	remaining: 575ms
# 8:	learn: 2756.2926453	total: 234ms	remaining: 545ms
# 9:	learn: 2690.9591516	total: 257ms	remaining: 513ms
# 10:	learn: 2630.1557163	total: 280ms	remaining: 484ms
# 11:	learn: 2571.1818599	total: 303ms	remaining: 455ms
# 12:	learn: 2516.6023033	total: 326ms	remaining: 427ms
# 13:	learn: 2467.2741445	total: 350ms	remaining: 400ms
# 14:	learn: 2421.7181279	total: 373ms	remaining: 373ms
# 15:	learn: 2377.5182429	total: 396ms	remaining: 346ms
# 16:	learn: 2338.3520154	total: 420ms	remaining: 321ms
# 17:	learn: 2298.6723643	total: 443ms	remaining: 295ms
# 18:	learn: 2262.2905652	total: 465ms	remaining: 269ms
# 19:	learn: 2229.1772581	total: 486ms	remaining: 243ms
# 20:	learn: 2199.4605672	total: 508ms	remaining: 218ms
# 21:	learn: 2171.1101546	total: 529ms	remaining: 192ms
# 22:	learn: 2141.9256752	total: 551ms	remaining: 168ms
# 23:	learn: 2117.0939260	total: 577ms	remaining: 144ms
# 24:	learn: 2091.8731469	total: 602ms	remaining: 120ms
# 25:	learn: 2067.9871544	total: 623ms	remaining: 95.8ms
# 26:	learn: 2047.5940399	total: 645ms	remaining: 71.6ms
# 27:	learn: 2028.2493303	total: 667ms	remaining: 47.6ms
# 28:	learn: 2009.6009375	total: 689ms	remaining: 23.8ms
# 29:	learn: 1992.4909683	total: 709ms	remaining: 0us
# 0:	learn: 3454.1532228	total: 21.8ms	remaining: 633ms
# 1:	learn: 3347.3929031	total: 43.9ms	remaining: 615ms
# 2:	learn: 3248.2993729	total: 67.6ms	remaining: 608ms
# 3:	learn: 3154.6708975	total: 89.6ms	remaining: 583ms
# 4:	learn: 3062.4044153	total: 113ms	remaining: 565ms
# 5:	learn: 2976.4829688	total: 135ms	remaining: 539ms
# 6:	learn: 2901.1317920	total: 159ms	remaining: 523ms
# 7:	learn: 2828.0500040	total: 181ms	remaining: 499ms
# 8:	learn: 2760.3466092	total: 204ms	remaining: 475ms
# 9:	learn: 2693.3559241	total: 226ms	remaining: 451ms
# 10:	learn: 2634.3147470	total: 252ms	remaining: 435ms
# 11:	learn: 2575.2619001	total: 273ms	remaining: 409ms
# 12:	learn: 2520.7549738	total: 295ms	remaining: 386ms
# 13:	learn: 2472.5096836	total: 319ms	remaining: 364ms
# 14:	learn: 2424.0838695	total: 343ms	remaining: 343ms
# 15:	learn: 2379.5827201	total: 364ms	remaining: 319ms
# 16:	learn: 2340.4731092	total: 385ms	remaining: 295ms
# 17:	learn: 2301.1430287	total: 407ms	remaining: 271ms
# 18:	learn: 2264.3464182	total: 437ms	remaining: 253ms
# 19:	learn: 2229.7556637	total: 468ms	remaining: 234ms
# 20:	learn: 2198.7803843	total: 489ms	remaining: 210ms
# 21:	learn: 2168.5049519	total: 509ms	remaining: 185ms
# 22:	learn: 2141.1709429	total: 539ms	remaining: 164ms
# 23:	learn: 2115.9474981	total: 564ms	remaining: 141ms
# 24:	learn: 2090.4812507	total: 586ms	remaining: 117ms
# 25:	learn: 2067.8007848	total: 611ms	remaining: 94ms
# 26:	learn: 2046.8465627	total: 636ms	remaining: 70.7ms
# 27:	learn: 2026.9388243	total: 658ms	remaining: 47ms
# 28:	learn: 2007.5848103	total: 680ms	remaining: 23.4ms
# 29:	learn: 1990.7657381	total: 702ms	remaining: 0us
# 0:	learn: 3461.1482973	total: 22.3ms	remaining: 646ms
# 1:	learn: 3353.9063640	total: 43.7ms	remaining: 612ms
# 2:	learn: 3255.1084576	total: 66.1ms	remaining: 595ms
# 3:	learn: 3161.3175965	total: 87.9ms	remaining: 571ms
# 4:	learn: 3068.5896613	total: 110ms	remaining: 548ms
# 5:	learn: 2982.2443510	total: 130ms	remaining: 522ms
# 6:	learn: 2906.5378811	total: 152ms	remaining: 501ms
# 7:	learn: 2833.4355310	total: 175ms	remaining: 481ms
# 8:	learn: 2764.8747415	total: 197ms	remaining: 460ms
# 9:	learn: 2697.9226412	total: 224ms	remaining: 449ms
# 10:	learn: 2638.9240610	total: 246ms	remaining: 426ms
# 11:	learn: 2579.5602339	total: 268ms	remaining: 401ms
# 12:	learn: 2526.1132531	total: 289ms	remaining: 377ms
# 13:	learn: 2476.6103821	total: 314ms	remaining: 359ms
# 14:	learn: 2429.1737617	total: 334ms	remaining: 334ms
# 15:	learn: 2384.5821757	total: 356ms	remaining: 311ms
# 16:	learn: 2344.6926641	total: 378ms	remaining: 289ms
# 17:	learn: 2304.9350804	total: 405ms	remaining: 270ms
# 18:	learn: 2267.4170867	total: 427ms	remaining: 247ms
# 19:	learn: 2234.9596138	total: 449ms	remaining: 224ms
# 20:	learn: 2205.1206448	total: 471ms	remaining: 202ms
# 21:	learn: 2176.4282093	total: 498ms	remaining: 181ms
# 22:	learn: 2147.2388474	total: 521ms	remaining: 158ms
# 23:	learn: 2122.6705115	total: 545ms	remaining: 136ms
# 24:	learn: 2096.6813549	total: 568ms	remaining: 114ms
# 25:	learn: 2073.1393068	total: 596ms	remaining: 91.8ms
# 26:	learn: 2051.0575032	total: 625ms	remaining: 69.5ms
# 27:	learn: 2030.8132282	total: 651ms	remaining: 46.5ms
# 28:	learn: 2011.9759373	total: 679ms	remaining: 23.4ms
# 29:	learn: 1995.2857849	total: 704ms	remaining: 0us
# 0:	learn: 3344.8277864	total: 21.1ms	remaining: 612ms
# 1:	learn: 3144.6194322	total: 42.3ms	remaining: 592ms
# 2:	learn: 2972.0913342	total: 69.8ms	remaining: 629ms
# 3:	learn: 2813.3808978	total: 90.9ms	remaining: 591ms
# 4:	learn: 2679.1440923	total: 119ms	remaining: 594ms
# 5:	learn: 2560.2436418	total: 144ms	remaining: 574ms
# 6:	learn: 2459.6617487	total: 172ms	remaining: 566ms
# 7:	learn: 2371.9344435	total: 195ms	remaining: 535ms
# 8:	learn: 2296.5432365	total: 217ms	remaining: 505ms
# 9:	learn: 2222.1184901	total: 240ms	remaining: 479ms
# 10:	learn: 2157.1720260	total: 270ms	remaining: 467ms
# 11:	learn: 2101.0789956	total: 292ms	remaining: 438ms
# 12:	learn: 2054.1594134	total: 314ms	remaining: 410ms
# 13:	learn: 2013.5349199	total: 335ms	remaining: 383ms
# 14:	learn: 1978.7854673	total: 362ms	remaining: 362ms
# 15:	learn: 1947.0204336	total: 385ms	remaining: 337ms
# 16:	learn: 1920.9862463	total: 405ms	remaining: 310ms
# 17:	learn: 1895.8753679	total: 427ms	remaining: 284ms
# 18:	learn: 1874.6251213	total: 451ms	remaining: 261ms
# 19:	learn: 1855.3225846	total: 473ms	remaining: 237ms
# 20:	learn: 1839.3494208	total: 494ms	remaining: 212ms
# 21:	learn: 1824.2958943	total: 514ms	remaining: 187ms
# 22:	learn: 1811.0220448	total: 536ms	remaining: 163ms
# 23:	learn: 1800.6586209	total: 561ms	remaining: 140ms
# 24:	learn: 1790.0739705	total: 581ms	remaining: 116ms
# 25:	learn: 1778.9334584	total: 600ms	remaining: 92.3ms
# 26:	learn: 1769.8540228	total: 619ms	remaining: 68.8ms
# 27:	learn: 1761.3936738	total: 640ms	remaining: 45.7ms
# 28:	learn: 1753.7590869	total: 662ms	remaining: 22.8ms
# 29:	learn: 1745.2689580	total: 684ms	remaining: 0us
# 0:	learn: 3344.2121310	total: 30.7ms	remaining: 891ms
# 1:	learn: 3144.7859736	total: 52ms	remaining: 728ms
# 2:	learn: 2972.3125461	total: 73.1ms	remaining: 658ms
# 3:	learn: 2820.4504822	total: 95.6ms	remaining: 622ms
# 4:	learn: 2689.7721914	total: 117ms	remaining: 584ms
# 5:	learn: 2566.3909699	total: 138ms	remaining: 550ms
# 6:	learn: 2462.9097510	total: 159ms	remaining: 523ms
# 7:	learn: 2372.1796193	total: 181ms	remaining: 497ms
# 8:	learn: 2291.3645110	total: 204ms	remaining: 476ms
# 9:	learn: 2218.1801259	total: 226ms	remaining: 452ms
# 10:	learn: 2157.0642991	total: 249ms	remaining: 430ms
# 11:	learn: 2103.8912176	total: 271ms	remaining: 406ms
# 12:	learn: 2056.9535218	total: 297ms	remaining: 389ms
# 13:	learn: 2017.7281775	total: 326ms	remaining: 372ms
# 14:	learn: 1981.4619595	total: 346ms	remaining: 346ms
# 15:	learn: 1950.4459581	total: 368ms	remaining: 322ms
# 16:	learn: 1924.4912967	total: 389ms	remaining: 297ms
# 17:	learn: 1898.9472796	total: 411ms	remaining: 274ms
# 18:	learn: 1877.8236948	total: 432ms	remaining: 250ms
# 19:	learn: 1859.5354310	total: 453ms	remaining: 226ms
# 20:	learn: 1844.2827749	total: 473ms	remaining: 203ms
# 21:	learn: 1829.9157303	total: 492ms	remaining: 179ms
# 22:	learn: 1816.2145828	total: 513ms	remaining: 156ms
# 23:	learn: 1802.8542917	total: 534ms	remaining: 133ms
# 24:	learn: 1789.0252414	total: 554ms	remaining: 111ms
# 25:	learn: 1778.3643732	total: 581ms	remaining: 89.4ms
# 26:	learn: 1768.6290118	total: 607ms	remaining: 67.4ms
# 27:	learn: 1759.4253415	total: 629ms	remaining: 44.9ms
# 28:	learn: 1752.1238698	total: 650ms	remaining: 22.4ms
# 29:	learn: 1744.4574236	total: 673ms	remaining: 0us
# 0:	learn: 3344.8537248	total: 21.6ms	remaining: 628ms
# 1:	learn: 3145.4468031	total: 44ms	remaining: 615ms
# 2:	learn: 2970.5370489	total: 73ms	remaining: 657ms
# 3:	learn: 2814.1525626	total: 96ms	remaining: 624ms
# 4:	learn: 2682.2773137	total: 118ms	remaining: 592ms
# 5:	learn: 2560.0424780	total: 140ms	remaining: 559ms
# 6:	learn: 2452.1570496	total: 168ms	remaining: 551ms
# 7:	learn: 2360.6968575	total: 192ms	remaining: 528ms
# 8:	learn: 2282.8272148	total: 214ms	remaining: 500ms
# 9:	learn: 2210.0187796	total: 237ms	remaining: 474ms
# 10:	learn: 2150.8517552	total: 265ms	remaining: 457ms
# 11:	learn: 2097.9872277	total: 289ms	remaining: 434ms
# 12:	learn: 2053.2321680	total: 311ms	remaining: 407ms
# 13:	learn: 2012.5368089	total: 333ms	remaining: 380ms
# 14:	learn: 1978.9740528	total: 353ms	remaining: 353ms
# 15:	learn: 1946.1642820	total: 383ms	remaining: 335ms
# 16:	learn: 1921.2157011	total: 415ms	remaining: 317ms
# 17:	learn: 1897.2914856	total: 443ms	remaining: 295ms
# 18:	learn: 1876.5541483	total: 471ms	remaining: 272ms
# 19:	learn: 1857.7689635	total: 493ms	remaining: 247ms
# 20:	learn: 1842.1813269	total: 515ms	remaining: 221ms
# 21:	learn: 1827.4379086	total: 536ms	remaining: 195ms
# 22:	learn: 1813.1800065	total: 571ms	remaining: 174ms
# 23:	learn: 1801.5940295	total: 592ms	remaining: 148ms
# 24:	learn: 1789.9506856	total: 613ms	remaining: 123ms
# 25:	learn: 1780.2763829	total: 637ms	remaining: 98.1ms
# 26:	learn: 1770.4302936	total: 658ms	remaining: 73.1ms
# 27:	learn: 1760.6985206	total: 678ms	remaining: 48.5ms
# 28:	learn: 1752.5942599	total: 699ms	remaining: 24.1ms
# 29:	learn: 1743.9119902	total: 719ms	remaining: 0us
# 0:	learn: 3344.0585139	total: 22.1ms	remaining: 642ms
# 1:	learn: 3144.8619185	total: 43.9ms	remaining: 615ms
# 2:	learn: 2969.7970169	total: 70.4ms	remaining: 633ms
# 3:	learn: 2813.1286613	total: 91.6ms	remaining: 596ms
# 4:	learn: 2680.8678151	total: 114ms	remaining: 571ms
# 5:	learn: 2560.2919338	total: 136ms	remaining: 544ms
# 6:	learn: 2456.5355335	total: 159ms	remaining: 523ms
# 7:	learn: 2364.7851762	total: 183ms	remaining: 504ms
# 8:	learn: 2288.7398290	total: 205ms	remaining: 477ms
# 9:	learn: 2217.5108815	total: 226ms	remaining: 451ms
# 10:	learn: 2159.4967995	total: 246ms	remaining: 426ms
# 11:	learn: 2104.2364238	total: 272ms	remaining: 408ms
# 12:	learn: 2056.2729015	total: 293ms	remaining: 383ms
# 13:	learn: 2012.9603996	total: 314ms	remaining: 359ms
# 14:	learn: 1979.6657037	total: 335ms	remaining: 335ms
# 15:	learn: 1949.4484009	total: 357ms	remaining: 312ms
# 16:	learn: 1921.3359973	total: 379ms	remaining: 290ms
# 17:	learn: 1896.3671529	total: 400ms	remaining: 267ms
# 18:	learn: 1876.0967066	total: 422ms	remaining: 244ms
# 19:	learn: 1858.7761486	total: 443ms	remaining: 221ms
# 20:	learn: 1840.2923121	total: 465ms	remaining: 199ms
# 21:	learn: 1826.1301314	total: 485ms	remaining: 177ms
# 22:	learn: 1812.1615041	total: 505ms	remaining: 154ms
# 23:	learn: 1799.9197973	total: 525ms	remaining: 131ms
# 24:	learn: 1789.4731139	total: 545ms	remaining: 109ms
# 25:	learn: 1780.2439904	total: 564ms	remaining: 86.7ms
# 26:	learn: 1769.0282617	total: 584ms	remaining: 64.9ms
# 27:	learn: 1760.1908883	total: 604ms	remaining: 43.1ms
# 28:	learn: 1751.5320687	total: 624ms	remaining: 21.5ms
# 29:	learn: 1743.3716816	total: 643ms	remaining: 0us
# 0:	learn: 3350.7182431	total: 29.1ms	remaining: 845ms
# 1:	learn: 3150.7429703	total: 51.7ms	remaining: 724ms
# 2:	learn: 2975.8631117	total: 87.9ms	remaining: 792ms
# 3:	learn: 2823.9410283	total: 115ms	remaining: 748ms
# 4:	learn: 2688.6108465	total: 138ms	remaining: 689ms
# 5:	learn: 2565.1663346	total: 161ms	remaining: 646ms
# 6:	learn: 2460.2479716	total: 183ms	remaining: 600ms
# 7:	learn: 2372.4542978	total: 204ms	remaining: 561ms
# 8:	learn: 2292.3276494	total: 227ms	remaining: 530ms
# 9:	learn: 2219.9630531	total: 250ms	remaining: 500ms
# 10:	learn: 2160.5780966	total: 275ms	remaining: 476ms
# 11:	learn: 2105.5212897	total: 298ms	remaining: 447ms
# 12:	learn: 2059.1197311	total: 321ms	remaining: 420ms
# 13:	learn: 2019.7412969	total: 343ms	remaining: 392ms
# 14:	learn: 1985.0776533	total: 366ms	remaining: 366ms
# 15:	learn: 1954.3952053	total: 391ms	remaining: 342ms
# 16:	learn: 1927.2443884	total: 412ms	remaining: 315ms
# 17:	learn: 1903.9769780	total: 434ms	remaining: 289ms
# 18:	learn: 1882.4598271	total: 456ms	remaining: 264ms
# 19:	learn: 1861.3761131	total: 481ms	remaining: 240ms
# 20:	learn: 1844.8738814	total: 502ms	remaining: 215ms
# 21:	learn: 1830.7575953	total: 523ms	remaining: 190ms
# 22:	learn: 1816.9039265	total: 543ms	remaining: 165ms
# 23:	learn: 1804.7494644	total: 567ms	remaining: 142ms
# 24:	learn: 1792.8638684	total: 589ms	remaining: 118ms
# 25:	learn: 1782.5083207	total: 609ms	remaining: 93.8ms
# 26:	learn: 1773.7695044	total: 631ms	remaining: 70.1ms
# 27:	learn: 1764.8870473	total: 654ms	remaining: 46.7ms
# 28:	learn: 1755.6740114	total: 678ms	remaining: 23.4ms
# 29:	learn: 1747.2732424	total: 699ms	remaining: 0us
# 0:	learn: 3544.6209765	total: 33.7ms	remaining: 1.65s
# 1:	learn: 3521.7832050	total: 55.2ms	remaining: 1.32s
# 2:	learn: 3499.5848716	total: 76.9ms	remaining: 1.2s
# 3:	learn: 3477.3192672	total: 98.6ms	remaining: 1.13s
# 4:	learn: 3455.5678060	total: 129ms	remaining: 1.16s
# 5:	learn: 3434.2583168	total: 151ms	remaining: 1.11s
# 6:	learn: 3412.8128401	total: 172ms	remaining: 1.06s
# 7:	learn: 3392.0070397	total: 193ms	remaining: 1.01s
# 8:	learn: 3371.4921136	total: 221ms	remaining: 1s
# 9:	learn: 3351.0959766	total: 242ms	remaining: 970ms
# 10:	learn: 3331.2234335	total: 264ms	remaining: 936ms
# 11:	learn: 3310.6473338	total: 285ms	remaining: 903ms
# 12:	learn: 3290.3859076	total: 309ms	remaining: 880ms
# 13:	learn: 3270.8419076	total: 334ms	remaining: 859ms
# 14:	learn: 3251.4708529	total: 356ms	remaining: 831ms
# 15:	learn: 3231.9267823	total: 377ms	remaining: 801ms
# 16:	learn: 3213.4968680	total: 398ms	remaining: 773ms
# 17:	learn: 3194.9667244	total: 422ms	remaining: 751ms
# 18:	learn: 3176.3479736	total: 445ms	remaining: 727ms
# 19:	learn: 3158.4030899	total: 468ms	remaining: 702ms
# 20:	learn: 3140.7420363	total: 496ms	remaining: 686ms
# 21:	learn: 3123.1695043	total: 521ms	remaining: 662ms
# 22:	learn: 3105.6853146	total: 543ms	remaining: 637ms
# 23:	learn: 3088.3406604	total: 565ms	remaining: 612ms
# 24:	learn: 3071.0620302	total: 587ms	remaining: 587ms
# 25:	learn: 3054.1562241	total: 611ms	remaining: 564ms
# 26:	learn: 3037.6368964	total: 633ms	remaining: 539ms
# 27:	learn: 3021.0203311	total: 654ms	remaining: 514ms
# 28:	learn: 3004.9207527	total: 676ms	remaining: 489ms
# 29:	learn: 2988.9735663	total: 702ms	remaining: 468ms
# 30:	learn: 2973.1325733	total: 723ms	remaining: 443ms
# 31:	learn: 2957.6084127	total: 744ms	remaining: 419ms
# 32:	learn: 2941.8455828	total: 765ms	remaining: 394ms
# 33:	learn: 2926.3073295	total: 789ms	remaining: 371ms
# 34:	learn: 2911.3736366	total: 812ms	remaining: 348ms
# 35:	learn: 2896.1111062	total: 834ms	remaining: 324ms
# 36:	learn: 2881.0779760	total: 854ms	remaining: 300ms
# 37:	learn: 2866.5505621	total: 876ms	remaining: 277ms
# 38:	learn: 2852.2480146	total: 901ms	remaining: 254ms
# 39:	learn: 2838.0183593	total: 922ms	remaining: 231ms
# 40:	learn: 2823.8341203	total: 943ms	remaining: 207ms
# 41:	learn: 2809.8094374	total: 964ms	remaining: 184ms
# 42:	learn: 2796.1695702	total: 991ms	remaining: 161ms
# 43:	learn: 2782.4553283	total: 1.01s	remaining: 138ms
# 44:	learn: 2769.0645435	total: 1.03s	remaining: 115ms
# 45:	learn: 2755.5368733	total: 1.05s	remaining: 91.6ms
# 46:	learn: 2742.1680024	total: 1.08s	remaining: 68.9ms
# 47:	learn: 2729.3498532	total: 1.1s	remaining: 45.9ms
# 48:	learn: 2716.5804739	total: 1.12s	remaining: 22.9ms
# 49:	learn: 2704.0472450	total: 1.14s	remaining: 0us
# 0:	learn: 3547.2612585	total: 21.3ms	remaining: 1.04s
# 1:	learn: 3524.9974871	total: 42.8ms	remaining: 1.03s
# 2:	learn: 3503.0170093	total: 65.5ms	remaining: 1.02s
# 3:	learn: 3480.9810756	total: 88.4ms	remaining: 1.02s
# 4:	learn: 3459.0325616	total: 110ms	remaining: 991ms
# 5:	learn: 3437.6122070	total: 132ms	remaining: 967ms
# 6:	learn: 3416.7358758	total: 154ms	remaining: 946ms
# 7:	learn: 3395.9795566	total: 177ms	remaining: 930ms
# 8:	learn: 3375.4285282	total: 200ms	remaining: 912ms
# 9:	learn: 3355.0339643	total: 223ms	remaining: 894ms
# 10:	learn: 3334.8309878	total: 245ms	remaining: 870ms
# 11:	learn: 3314.1580152	total: 266ms	remaining: 844ms
# 12:	learn: 3293.9097487	total: 289ms	remaining: 823ms
# 13:	learn: 3274.6667933	total: 322ms	remaining: 828ms
# 14:	learn: 3255.6340804	total: 344ms	remaining: 804ms
# 15:	learn: 3236.4326124	total: 366ms	remaining: 778ms
# 16:	learn: 3217.6658592	total: 387ms	remaining: 752ms
# 17:	learn: 3198.6665987	total: 410ms	remaining: 729ms
# 18:	learn: 3180.2317476	total: 435ms	remaining: 710ms
# 19:	learn: 3162.2149166	total: 461ms	remaining: 691ms
# 20:	learn: 3144.3947984	total: 487ms	remaining: 672ms
# 21:	learn: 3126.8578850	total: 514ms	remaining: 654ms
# 22:	learn: 3108.8880594	total: 541ms	remaining: 635ms
# 23:	learn: 3091.6829308	total: 573ms	remaining: 620ms
# 24:	learn: 3074.2222813	total: 597ms	remaining: 597ms
# 25:	learn: 3057.4899731	total: 622ms	remaining: 574ms
# 26:	learn: 3040.2757287	total: 644ms	remaining: 549ms
# 27:	learn: 3023.6574196	total: 666ms	remaining: 524ms
# 28:	learn: 3007.5513167	total: 688ms	remaining: 498ms
# 29:	learn: 2991.6937483	total: 709ms	remaining: 473ms
# 30:	learn: 2975.8194717	total: 730ms	remaining: 447ms
# 31:	learn: 2960.0451518	total: 752ms	remaining: 423ms
# 32:	learn: 2944.1519287	total: 772ms	remaining: 398ms
# 33:	learn: 2928.6382722	total: 795ms	remaining: 374ms
# 34:	learn: 2913.6167810	total: 817ms	remaining: 350ms
# 35:	learn: 2898.8907850	total: 839ms	remaining: 326ms
# 36:	learn: 2883.9087084	total: 861ms	remaining: 303ms
# 37:	learn: 2869.3048110	total: 884ms	remaining: 279ms
# 38:	learn: 2854.7755145	total: 906ms	remaining: 255ms
# 39:	learn: 2840.7813268	total: 928ms	remaining: 232ms
# 40:	learn: 2826.8451036	total: 949ms	remaining: 208ms
# 41:	learn: 2812.6583139	total: 969ms	remaining: 185ms
# 42:	learn: 2799.0377370	total: 995ms	remaining: 162ms
# 43:	learn: 2785.1798501	total: 1.02s	remaining: 139ms
# 44:	learn: 2771.7734135	total: 1.04s	remaining: 116ms
# 45:	learn: 2758.2653383	total: 1.06s	remaining: 92.3ms
# 46:	learn: 2745.3500940	total: 1.08s	remaining: 69.1ms
# 47:	learn: 2732.7206794	total: 1.1s	remaining: 46ms
# 48:	learn: 2720.1517455	total: 1.13s	remaining: 23ms
# 49:	learn: 2707.7692681	total: 1.15s	remaining: 0us
# 0:	learn: 3544.9408446	total: 21.2ms	remaining: 1.04s
# 1:	learn: 3522.3269624	total: 43.1ms	remaining: 1.03s
# 2:	learn: 3500.3023030	total: 67.4ms	remaining: 1.05s
# 3:	learn: 3478.2510655	total: 90ms	remaining: 1.03s
# 4:	learn: 3456.4463988	total: 112ms	remaining: 1.01s
# 5:	learn: 3434.9775173	total: 134ms	remaining: 984ms
# 6:	learn: 3414.0252434	total: 156ms	remaining: 958ms
# 7:	learn: 3393.2576677	total: 178ms	remaining: 935ms
# 8:	learn: 3372.6778635	total: 217ms	remaining: 990ms
# 9:	learn: 3352.2367123	total: 242ms	remaining: 968ms
# 10:	learn: 3332.2959905	total: 266ms	remaining: 943ms
# 11:	learn: 3311.6563455	total: 288ms	remaining: 912ms
# 12:	learn: 3291.3584691	total: 320ms	remaining: 910ms
# 13:	learn: 3272.0532600	total: 343ms	remaining: 882ms
# 14:	learn: 3252.9927142	total: 365ms	remaining: 851ms
# 15:	learn: 3233.3770364	total: 387ms	remaining: 822ms
# 16:	learn: 3214.9359517	total: 409ms	remaining: 794ms
# 17:	learn: 3195.7801262	total: 431ms	remaining: 766ms
# 18:	learn: 3177.2923716	total: 453ms	remaining: 739ms
# 19:	learn: 3158.7758852	total: 474ms	remaining: 711ms
# 20:	learn: 3140.6232161	total: 496ms	remaining: 685ms
# 21:	learn: 3122.7462607	total: 517ms	remaining: 658ms
# 22:	learn: 3105.3065087	total: 538ms	remaining: 631ms
# 23:	learn: 3088.1376664	total: 559ms	remaining: 606ms
# 24:	learn: 3070.6171934	total: 581ms	remaining: 581ms
# 25:	learn: 3054.0085618	total: 604ms	remaining: 558ms
# 26:	learn: 3036.8330525	total: 626ms	remaining: 533ms
# 27:	learn: 3020.2343829	total: 648ms	remaining: 509ms
# 28:	learn: 3004.1673701	total: 674ms	remaining: 488ms
# 29:	learn: 2988.1841123	total: 695ms	remaining: 464ms
# 30:	learn: 2972.3459382	total: 717ms	remaining: 439ms
# 31:	learn: 2956.9636566	total: 738ms	remaining: 415ms
# 32:	learn: 2941.2792011	total: 758ms	remaining: 391ms
# 33:	learn: 2925.7650508	total: 779ms	remaining: 367ms
# 34:	learn: 2910.7079990	total: 800ms	remaining: 343ms
# 35:	learn: 2895.4438997	total: 821ms	remaining: 319ms
# 36:	learn: 2880.6120123	total: 841ms	remaining: 296ms
# 37:	learn: 2865.9151953	total: 862ms	remaining: 272ms
# 38:	learn: 2851.6085536	total: 883ms	remaining: 249ms
# 39:	learn: 2837.5047357	total: 905ms	remaining: 226ms
# 40:	learn: 2823.4937486	total: 926ms	remaining: 203ms
# 41:	learn: 2809.5280846	total: 947ms	remaining: 180ms
# 42:	learn: 2796.2616183	total: 968ms	remaining: 158ms
# 43:	learn: 2782.3193269	total: 989ms	remaining: 135ms
# 44:	learn: 2769.0075810	total: 1.01s	remaining: 112ms
# 45:	learn: 2755.5138123	total: 1.03s	remaining: 89.7ms
# 46:	learn: 2742.5700365	total: 1.05s	remaining: 67.2ms
# 47:	learn: 2729.6047309	total: 1.07s	remaining: 44.8ms
# 48:	learn: 2716.9962186	total: 1.1s	remaining: 22.4ms
# 49:	learn: 2704.5744123	total: 1.12s	remaining: 0us
# 0:	learn: 3543.8743780	total: 24.7ms	remaining: 1.21s
# 1:	learn: 3521.4337917	total: 45.4ms	remaining: 1.09s
# 2:	learn: 3499.4496263	total: 68.4ms	remaining: 1.07s
# 3:	learn: 3477.4104912	total: 89.8ms	remaining: 1.03s
# 4:	learn: 3455.3882040	total: 111ms	remaining: 999ms
# 5:	learn: 3434.2911711	total: 133ms	remaining: 976ms
# 6:	learn: 3412.8112634	total: 156ms	remaining: 959ms
# 7:	learn: 3392.1335722	total: 184ms	remaining: 966ms
# 8:	learn: 3371.5611910	total: 208ms	remaining: 945ms
# 9:	learn: 3351.1634203	total: 229ms	remaining: 916ms
# 10:	learn: 3330.9793514	total: 251ms	remaining: 890ms
# 11:	learn: 3310.4045726	total: 272ms	remaining: 862ms
# 12:	learn: 3290.1363930	total: 293ms	remaining: 834ms
# 13:	learn: 3270.8112615	total: 315ms	remaining: 810ms
# 14:	learn: 3251.9185714	total: 336ms	remaining: 783ms
# 15:	learn: 3232.9268199	total: 358ms	remaining: 761ms
# 16:	learn: 3214.2522068	total: 380ms	remaining: 738ms
# 17:	learn: 3195.2795179	total: 401ms	remaining: 712ms
# 18:	learn: 3176.6052170	total: 422ms	remaining: 688ms
# 19:	learn: 3158.0461142	total: 444ms	remaining: 666ms
# 20:	learn: 3139.9392220	total: 465ms	remaining: 642ms
# 21:	learn: 3122.3902570	total: 488ms	remaining: 621ms
# 22:	learn: 3104.4857583	total: 514ms	remaining: 603ms
# 23:	learn: 3087.2257204	total: 536ms	remaining: 581ms
# 24:	learn: 3069.8441272	total: 559ms	remaining: 559ms
# 25:	learn: 3053.2415944	total: 582ms	remaining: 537ms
# 26:	learn: 3036.3872703	total: 603ms	remaining: 514ms
# 27:	learn: 3019.7805068	total: 626ms	remaining: 492ms
# 28:	learn: 3003.6894367	total: 648ms	remaining: 470ms
# 29:	learn: 2987.8351191	total: 671ms	remaining: 447ms
# 30:	learn: 2971.9702688	total: 692ms	remaining: 424ms
# 31:	learn: 2956.2072831	total: 715ms	remaining: 402ms
# 32:	learn: 2940.3363305	total: 737ms	remaining: 380ms
# 33:	learn: 2924.8583439	total: 760ms	remaining: 358ms
# 34:	learn: 2909.8212441	total: 782ms	remaining: 335ms
# 35:	learn: 2894.5577041	total: 804ms	remaining: 313ms
# 36:	learn: 2879.6060665	total: 826ms	remaining: 290ms
# 37:	learn: 2864.9601266	total: 848ms	remaining: 268ms
# 38:	learn: 2850.6471592	total: 871ms	remaining: 246ms
# 39:	learn: 2836.5611117	total: 897ms	remaining: 224ms
# 40:	learn: 2822.4065595	total: 920ms	remaining: 202ms
# 41:	learn: 2808.4590588	total: 943ms	remaining: 180ms
# 42:	learn: 2794.8066147	total: 965ms	remaining: 157ms
# 43:	learn: 2781.2130776	total: 987ms	remaining: 135ms
# 44:	learn: 2767.7231510	total: 1.01s	remaining: 112ms
# 45:	learn: 2754.2288093	total: 1.03s	remaining: 89.5ms
# 46:	learn: 2741.1222884	total: 1.05s	remaining: 67.1ms
# 47:	learn: 2728.2871543	total: 1.07s	remaining: 44.7ms
# 48:	learn: 2715.3936137	total: 1.1s	remaining: 22.4ms
# 49:	learn: 2702.9695390	total: 1.12s	remaining: 0us
# 0:	learn: 3551.1401178	total: 29.7ms	remaining: 1.46s
# 1:	learn: 3528.5506364	total: 52ms	remaining: 1.25s
# 2:	learn: 3506.5218296	total: 75.3ms	remaining: 1.18s
# 3:	learn: 3484.3887670	total: 98ms	remaining: 1.13s
# 4:	learn: 3462.8341182	total: 134ms	remaining: 1.21s
# 5:	learn: 3441.1217988	total: 173ms	remaining: 1.27s
# 6:	learn: 3420.1368422	total: 198ms	remaining: 1.21s
# 7:	learn: 3399.2700851	total: 220ms	remaining: 1.16s
# 8:	learn: 3378.6130435	total: 245ms	remaining: 1.11s
# 9:	learn: 3357.7574598	total: 267ms	remaining: 1.07s
# 10:	learn: 3337.7551200	total: 289ms	remaining: 1.02s
# 11:	learn: 3317.3650904	total: 312ms	remaining: 989ms
# 12:	learn: 3297.0475054	total: 335ms	remaining: 954ms
# 13:	learn: 3277.6481866	total: 357ms	remaining: 919ms
# 14:	learn: 3258.1532260	total: 379ms	remaining: 884ms
# 15:	learn: 3239.0963075	total: 401ms	remaining: 851ms
# 16:	learn: 3220.0514066	total: 423ms	remaining: 821ms
# 17:	learn: 3201.0065287	total: 447ms	remaining: 794ms
# 18:	learn: 3182.2922621	total: 469ms	remaining: 766ms
# 19:	learn: 3163.6878056	total: 491ms	remaining: 737ms
# 20:	learn: 3145.8563096	total: 514ms	remaining: 710ms
# 21:	learn: 3128.2940679	total: 536ms	remaining: 682ms
# 22:	learn: 3110.8405737	total: 559ms	remaining: 656ms
# 23:	learn: 3093.6183394	total: 582ms	remaining: 631ms
# 24:	learn: 3076.3956928	total: 604ms	remaining: 604ms
# 25:	learn: 3059.3156187	total: 626ms	remaining: 578ms
# 26:	learn: 3042.0911342	total: 649ms	remaining: 553ms
# 27:	learn: 3025.4452380	total: 675ms	remaining: 530ms
# 28:	learn: 3009.2971695	total: 698ms	remaining: 505ms
# 29:	learn: 2993.4531344	total: 721ms	remaining: 481ms
# 30:	learn: 2977.5758146	total: 743ms	remaining: 456ms
# 31:	learn: 2962.0741391	total: 766ms	remaining: 431ms
# 32:	learn: 2946.3425635	total: 788ms	remaining: 406ms
# 33:	learn: 2930.7781987	total: 810ms	remaining: 381ms
# 34:	learn: 2915.6667872	total: 832ms	remaining: 357ms
# 35:	learn: 2900.8589899	total: 853ms	remaining: 332ms
# 36:	learn: 2885.8170900	total: 878ms	remaining: 308ms
# 37:	learn: 2871.1358761	total: 899ms	remaining: 284ms
# 38:	learn: 2856.6056233	total: 920ms	remaining: 260ms
# 39:	learn: 2842.4937901	total: 943ms	remaining: 236ms
# 40:	learn: 2828.4768217	total: 966ms	remaining: 212ms
# 41:	learn: 2814.5038460	total: 989ms	remaining: 188ms
# 42:	learn: 2800.8039029	total: 1.01s	remaining: 165ms
# 43:	learn: 2786.8690286	total: 1.03s	remaining: 141ms
# 44:	learn: 2773.4017147	total: 1.05s	remaining: 117ms
# 45:	learn: 2759.8340300	total: 1.08s	remaining: 93.6ms
# 46:	learn: 2746.8571376	total: 1.1s	remaining: 70.1ms
# 47:	learn: 2734.1684619	total: 1.12s	remaining: 46.7ms
# 48:	learn: 2721.4967261	total: 1.14s	remaining: 23.3ms
# 49:	learn: 2709.0576900	total: 1.16s	remaining: 0us
# 0:	learn: 3454.9095270	total: 22.5ms	remaining: 1.1s
# 1:	learn: 3347.9894700	total: 44.2ms	remaining: 1.06s
# 2:	learn: 3249.0484720	total: 69ms	remaining: 1.08s
# 3:	learn: 3150.9679739	total: 91.6ms	remaining: 1.05s
# 4:	learn: 3062.6322324	total: 114ms	remaining: 1.02s
# 5:	learn: 2977.4508982	total: 135ms	remaining: 987ms
# 6:	learn: 2902.0643303	total: 157ms	remaining: 964ms
# 7:	learn: 2828.5479472	total: 179ms	remaining: 939ms
# 8:	learn: 2759.0254233	total: 201ms	remaining: 916ms
# 9:	learn: 2691.7380079	total: 224ms	remaining: 894ms
# 10:	learn: 2632.2572171	total: 246ms	remaining: 872ms
# 11:	learn: 2573.8486963	total: 266ms	remaining: 844ms
# 12:	learn: 2518.9843712	total: 291ms	remaining: 828ms
# 13:	learn: 2469.6266013	total: 313ms	remaining: 804ms
# 14:	learn: 2421.8144561	total: 333ms	remaining: 777ms
# 15:	learn: 2378.0837476	total: 354ms	remaining: 753ms
# 16:	learn: 2338.3525777	total: 375ms	remaining: 728ms
# 17:	learn: 2300.8692849	total: 397ms	remaining: 705ms
# 18:	learn: 2262.9888921	total: 418ms	remaining: 683ms
# 19:	learn: 2228.3730399	total: 440ms	remaining: 660ms
# 20:	learn: 2198.0488591	total: 461ms	remaining: 637ms
# 21:	learn: 2169.3013355	total: 485ms	remaining: 617ms
# 22:	learn: 2140.9105311	total: 506ms	remaining: 594ms
# 23:	learn: 2116.5855442	total: 527ms	remaining: 570ms
# 24:	learn: 2091.5856458	total: 550ms	remaining: 550ms
# 25:	learn: 2068.5544734	total: 571ms	remaining: 527ms
# 26:	learn: 2047.3615413	total: 592ms	remaining: 505ms
# 27:	learn: 2027.8502919	total: 614ms	remaining: 482ms
# 28:	learn: 2008.0378937	total: 636ms	remaining: 461ms
# 29:	learn: 1990.4607583	total: 657ms	remaining: 438ms
# 30:	learn: 1974.1055827	total: 682ms	remaining: 418ms
# 31:	learn: 1959.1586791	total: 704ms	remaining: 396ms
# 32:	learn: 1943.9765778	total: 725ms	remaining: 373ms
# 33:	learn: 1930.4708044	total: 746ms	remaining: 351ms
# 34:	learn: 1917.9114190	total: 768ms	remaining: 329ms
# 35:	learn: 1905.3910531	total: 791ms	remaining: 307ms
# 36:	learn: 1894.1102509	total: 812ms	remaining: 285ms
# 37:	learn: 1883.9292302	total: 836ms	remaining: 264ms
# 38:	learn: 1874.0619976	total: 858ms	remaining: 242ms
# 39:	learn: 1864.9802214	total: 881ms	remaining: 220ms
# 40:	learn: 1855.7167192	total: 903ms	remaining: 198ms
# 41:	learn: 1847.3338005	total: 925ms	remaining: 176ms
# 42:	learn: 1839.4930238	total: 947ms	remaining: 154ms
# 43:	learn: 1832.0693302	total: 969ms	remaining: 132ms
# 44:	learn: 1825.1604524	total: 992ms	remaining: 110ms
# 45:	learn: 1818.4356896	total: 1.01s	remaining: 88.1ms
# 46:	learn: 1812.2144708	total: 1.03s	remaining: 66ms
# 47:	learn: 1806.4144560	total: 1.05s	remaining: 44ms
# 48:	learn: 1800.1056508	total: 1.08s	remaining: 22.1ms
# 49:	learn: 1793.3809619	total: 1.1s	remaining: 0us
# 0:	learn: 3456.1111503	total: 29.4ms	remaining: 1.44s
# 1:	learn: 3348.9580717	total: 53.9ms	remaining: 1.29s
# 2:	learn: 3250.4834789	total: 77.2ms	remaining: 1.21s
# 3:	learn: 3156.2998020	total: 108ms	remaining: 1.24s
# 4:	learn: 3067.8464575	total: 140ms	remaining: 1.26s
# 5:	learn: 2984.3696482	total: 162ms	remaining: 1.18s
# 6:	learn: 2906.8788896	total: 183ms	remaining: 1.12s
# 7:	learn: 2833.4635740	total: 205ms	remaining: 1.08s
# 8:	learn: 2764.7310885	total: 228ms	remaining: 1.04s
# 9:	learn: 2698.1313631	total: 251ms	remaining: 1s
# 10:	learn: 2639.3245971	total: 273ms	remaining: 967ms
# 11:	learn: 2580.1826890	total: 295ms	remaining: 933ms
# 12:	learn: 2525.8165022	total: 316ms	remaining: 899ms
# 13:	learn: 2476.1786934	total: 338ms	remaining: 870ms
# 14:	learn: 2429.8424893	total: 359ms	remaining: 838ms
# 15:	learn: 2384.4389406	total: 380ms	remaining: 807ms
# 16:	learn: 2344.8462277	total: 403ms	remaining: 782ms
# 17:	learn: 2307.6511463	total: 429ms	remaining: 762ms
# 18:	learn: 2269.4001097	total: 451ms	remaining: 735ms
# 19:	learn: 2235.5160476	total: 473ms	remaining: 710ms
# 20:	learn: 2203.5699437	total: 498ms	remaining: 688ms
# 21:	learn: 2174.3237514	total: 520ms	remaining: 662ms
# 22:	learn: 2145.5437633	total: 542ms	remaining: 636ms
# 23:	learn: 2118.1619346	total: 564ms	remaining: 611ms
# 24:	learn: 2093.0260294	total: 588ms	remaining: 588ms
# 25:	learn: 2070.2647165	total: 609ms	remaining: 562ms
# 26:	learn: 2049.4872902	total: 633ms	remaining: 539ms
# 27:	learn: 2029.5489023	total: 655ms	remaining: 515ms
# 28:	learn: 2010.7418367	total: 676ms	remaining: 490ms
# 29:	learn: 1992.9162202	total: 697ms	remaining: 465ms
# 30:	learn: 1976.2281478	total: 719ms	remaining: 440ms
# 31:	learn: 1961.2141396	total: 741ms	remaining: 417ms
# 32:	learn: 1947.4128959	total: 765ms	remaining: 394ms
# 33:	learn: 1933.3993854	total: 787ms	remaining: 370ms
# 34:	learn: 1920.6031989	total: 809ms	remaining: 347ms
# 35:	learn: 1908.4120515	total: 830ms	remaining: 323ms
# 36:	learn: 1897.7037901	total: 851ms	remaining: 299ms
# 37:	learn: 1886.3568039	total: 888ms	remaining: 280ms
# 38:	learn: 1876.5924390	total: 912ms	remaining: 257ms
# 39:	learn: 1868.0169692	total: 935ms	remaining: 234ms
# 40:	learn: 1859.2346775	total: 955ms	remaining: 210ms
# 41:	learn: 1850.9000097	total: 976ms	remaining: 186ms
# 42:	learn: 1843.3922150	total: 997ms	remaining: 162ms
# 43:	learn: 1835.7762134	total: 1.02s	remaining: 139ms
# 44:	learn: 1829.0521056	total: 1.04s	remaining: 115ms
# 45:	learn: 1822.2974775	total: 1.06s	remaining: 92.1ms
# 46:	learn: 1815.9587178	total: 1.08s	remaining: 69.2ms
# 47:	learn: 1810.0259085	total: 1.1s	remaining: 46ms
# 48:	learn: 1804.7161647	total: 1.12s	remaining: 22.9ms
# 49:	learn: 1798.9439706	total: 1.14s	remaining: 0us
# 0:	learn: 3455.0994567	total: 23.8ms	remaining: 1.17s
# 1:	learn: 3347.4236467	total: 46.5ms	remaining: 1.12s
# 2:	learn: 3248.8193223	total: 68.6ms	remaining: 1.07s
# 3:	learn: 3155.4728480	total: 90.5ms	remaining: 1.04s
# 4:	learn: 3063.0169821	total: 112ms	remaining: 1.01s
# 5:	learn: 2976.7562035	total: 133ms	remaining: 978ms
# 6:	learn: 2899.2424058	total: 155ms	remaining: 953ms
# 7:	learn: 2825.4617963	total: 178ms	remaining: 933ms
# 8:	learn: 2756.2926453	total: 201ms	remaining: 914ms
# 9:	learn: 2690.9591516	total: 223ms	remaining: 890ms
# 10:	learn: 2630.1557163	total: 244ms	remaining: 867ms
# 11:	learn: 2571.1818599	total: 266ms	remaining: 844ms
# 12:	learn: 2516.6023033	total: 291ms	remaining: 828ms
# 13:	learn: 2467.2741445	total: 317ms	remaining: 814ms
# 14:	learn: 2421.7181279	total: 347ms	remaining: 809ms
# 15:	learn: 2377.5182429	total: 368ms	remaining: 782ms
# 16:	learn: 2338.3520154	total: 391ms	remaining: 758ms
# 17:	learn: 2298.6723643	total: 412ms	remaining: 733ms
# 18:	learn: 2262.2905652	total: 435ms	remaining: 710ms
# 19:	learn: 2229.1772581	total: 465ms	remaining: 698ms
# 20:	learn: 2199.4605672	total: 488ms	remaining: 674ms
# 21:	learn: 2171.1101546	total: 510ms	remaining: 649ms
# 22:	learn: 2141.9256752	total: 532ms	remaining: 625ms
# 23:	learn: 2117.0939260	total: 554ms	remaining: 600ms
# 24:	learn: 2091.8731469	total: 576ms	remaining: 576ms
# 25:	learn: 2067.9871544	total: 598ms	remaining: 552ms
# 26:	learn: 2047.5940399	total: 620ms	remaining: 528ms
# 27:	learn: 2028.2493303	total: 644ms	remaining: 506ms
# 28:	learn: 2009.6009375	total: 665ms	remaining: 482ms
# 29:	learn: 1992.4909683	total: 690ms	remaining: 460ms
# 30:	learn: 1975.7975122	total: 711ms	remaining: 436ms
# 31:	learn: 1960.7341414	total: 733ms	remaining: 412ms
# 32:	learn: 1945.6396782	total: 754ms	remaining: 388ms
# 33:	learn: 1931.6438685	total: 775ms	remaining: 365ms
# 34:	learn: 1918.7087832	total: 795ms	remaining: 341ms
# 35:	learn: 1907.4681201	total: 815ms	remaining: 317ms
# 36:	learn: 1896.7537113	total: 836ms	remaining: 294ms
# 37:	learn: 1885.3807621	total: 856ms	remaining: 270ms
# 38:	learn: 1875.7449238	total: 880ms	remaining: 248ms
# 39:	learn: 1866.9318013	total: 900ms	remaining: 225ms
# 40:	learn: 1858.3766667	total: 921ms	remaining: 202ms
# 41:	learn: 1850.0647398	total: 942ms	remaining: 179ms
# 42:	learn: 1841.3325236	total: 963ms	remaining: 157ms
# 43:	learn: 1834.1987792	total: 986ms	remaining: 134ms
# 44:	learn: 1827.1351878	total: 1.01s	remaining: 112ms
# 45:	learn: 1820.7226793	total: 1.03s	remaining: 89.3ms
# 46:	learn: 1814.1588417	total: 1.05s	remaining: 66.9ms
# 47:	learn: 1808.0432307	total: 1.07s	remaining: 44.8ms
# 48:	learn: 1802.4113687	total: 1.09s	remaining: 22.4ms
# 49:	learn: 1796.7833779	total: 1.12s	remaining: 0us
# 0:	learn: 3454.1532228	total: 25.5ms	remaining: 1.25s
# 1:	learn: 3347.3929031	total: 46.6ms	remaining: 1.12s
# 2:	learn: 3248.2993729	total: 69.4ms	remaining: 1.09s
# 3:	learn: 3154.6708975	total: 90.8ms	remaining: 1.04s
# 4:	learn: 3062.4044153	total: 112ms	remaining: 1.01s
# 5:	learn: 2976.4829688	total: 135ms	remaining: 990ms
# 6:	learn: 2901.1317920	total: 156ms	remaining: 961ms
# 7:	learn: 2828.0500040	total: 180ms	remaining: 943ms
# 8:	learn: 2760.3466092	total: 203ms	remaining: 924ms
# 9:	learn: 2693.3559241	total: 224ms	remaining: 898ms
# 10:	learn: 2634.3147470	total: 246ms	remaining: 873ms
# 11:	learn: 2575.2619001	total: 268ms	remaining: 848ms
# 12:	learn: 2520.7549738	total: 290ms	remaining: 827ms
# 13:	learn: 2472.5096836	total: 312ms	remaining: 802ms
# 14:	learn: 2424.0838695	total: 332ms	remaining: 775ms
# 15:	learn: 2379.5827201	total: 353ms	remaining: 750ms
# 16:	learn: 2340.4731092	total: 375ms	remaining: 728ms
# 17:	learn: 2301.1430287	total: 396ms	remaining: 704ms
# 18:	learn: 2264.3464182	total: 418ms	remaining: 682ms
# 19:	learn: 2229.7556637	total: 440ms	remaining: 661ms
# 20:	learn: 2198.7803843	total: 461ms	remaining: 637ms
# 21:	learn: 2168.5049519	total: 481ms	remaining: 612ms
# 22:	learn: 2141.1709429	total: 502ms	remaining: 590ms
# 23:	learn: 2115.9474981	total: 525ms	remaining: 568ms
# 24:	learn: 2090.4812507	total: 546ms	remaining: 546ms
# 25:	learn: 2067.8007848	total: 569ms	remaining: 525ms
# 26:	learn: 2046.8465627	total: 592ms	remaining: 504ms
# 27:	learn: 2026.9388243	total: 613ms	remaining: 482ms
# 28:	learn: 2007.5848103	total: 635ms	remaining: 460ms
# 29:	learn: 1990.7657381	total: 656ms	remaining: 438ms
# 30:	learn: 1973.9782822	total: 678ms	remaining: 416ms
# 31:	learn: 1959.2305789	total: 701ms	remaining: 394ms
# 32:	learn: 1944.8855486	total: 723ms	remaining: 372ms
# 33:	learn: 1930.5970611	total: 744ms	remaining: 350ms
# 34:	learn: 1918.4375836	total: 766ms	remaining: 328ms
# 35:	learn: 1906.0577710	total: 788ms	remaining: 306ms
# 36:	learn: 1895.0521981	total: 810ms	remaining: 285ms
# 37:	learn: 1885.0802535	total: 833ms	remaining: 263ms
# 38:	learn: 1875.4190698	total: 855ms	remaining: 241ms
# 39:	learn: 1865.1351494	total: 878ms	remaining: 219ms
# 40:	learn: 1855.9158857	total: 900ms	remaining: 197ms
# ...
# 3:	learn: 2739.7764116	total: 179ms	remaining: 4.3s
# 4:	learn: 2591.2312186	total: 221ms	remaining: 4.2s
# 5:	learn: 2463.2089311	total: 263ms	remaining: 4.12s
# 6:	learn: 2352.9776899	total: 306ms	remaining: 4.07s
# 7:	learn: 2257.1111362	total: 346ms	remaining: 3.98s
# 8:	learn: 2171.2015070	total: 385ms	remaining: 3.89s
# 9:	learn: 2100.9240274	total: 425ms	remaining: 3.82s
# 10:	learn: 2039.6032827	total: 463ms	remaining: 3.75s
# 11:	learn: 1986.9287075	total: 507ms	remaining: 3.72s
# 12:	learn: 1941.6485370	total: 547ms	remaining: 3.66s
# 13:	learn: 1901.8271477	total: 586ms	remaining: 3.6s
# 14:	learn: 1866.9923480	total: 625ms	remaining: 3.54s
# 15:	learn: 1836.8320819	total: 664ms	remaining: 3.48s
# 16:	learn: 1811.2588006	total: 701ms	remaining: 3.42s
# 17:	learn: 1788.3200899	total: 740ms	remaining: 3.37s
# 18:	learn: 1768.0863330	total: 779ms	remaining: 3.32s
# 19:	learn: 1750.7694826	total: 818ms	remaining: 3.27s
# 20:	learn: 1734.6877039	total: 857ms	remaining: 3.22s
# 21:	learn: 1718.9820277	total: 895ms	remaining: 3.17s
# 22:	learn: 1705.6006423	total: 933ms	remaining: 3.12s
# 23:	learn: 1689.3159851	total: 976ms	remaining: 3.09s
# 24:	learn: 1676.1427430	total: 1.01s	remaining: 3.04s
# 25:	learn: 1666.0609970	total: 1.05s	remaining: 2.99s
# 26:	learn: 1657.1014203	total: 1.09s	remaining: 2.94s
# 27:	learn: 1646.8886432	total: 1.13s	remaining: 2.9s
# 28:	learn: 1638.1735287	total: 1.17s	remaining: 2.86s
# 29:	learn: 1630.4528725	total: 1.21s	remaining: 2.82s
# 30:	learn: 1624.2427710	total: 1.27s	remaining: 2.82s
# 31:	learn: 1619.0523095	total: 1.31s	remaining: 2.78s
# 32:	learn: 1609.9008528	total: 1.35s	remaining: 2.73s
# 33:	learn: 1604.7764158	total: 1.39s	remaining: 2.69s
# 34:	learn: 1597.7563799	total: 1.43s	remaining: 2.65s
# 35:	learn: 1592.6474021	total: 1.47s	remaining: 2.6s
# 36:	learn: 1587.1006558	total: 1.51s	remaining: 2.56s
# 37:	learn: 1582.0032761	total: 1.55s	remaining: 2.52s
# 38:	learn: 1577.6202457	total: 1.59s	remaining: 2.49s
# 39:	learn: 1574.4394492	total: 1.63s	remaining: 2.45s
# 40:	learn: 1570.4799701	total: 1.68s	remaining: 2.42s
# 41:	learn: 1564.5067253	total: 1.72s	remaining: 2.38s
# 42:	learn: 1560.7537770	total: 1.78s	remaining: 2.36s
# 43:	learn: 1557.2822766	total: 1.84s	remaining: 2.34s
# 44:	learn: 1554.3597932	total: 1.9s	remaining: 2.32s
# 45:	learn: 1550.9907419	total: 1.94s	remaining: 2.28s
# 46:	learn: 1548.5487310	total: 1.98s	remaining: 2.23s
# 47:	learn: 1545.6387186	total: 2.02s	remaining: 2.19s
# 48:	learn: 1542.4068560	total: 2.06s	remaining: 2.15s
# 49:	learn: 1540.7646520	total: 2.11s	remaining: 2.11s
# 50:	learn: 1538.0999177	total: 2.15s	remaining: 2.07s
# 51:	learn: 1535.8249152	total: 2.19s	remaining: 2.02s
# 52:	learn: 1532.7823794	total: 2.23s	remaining: 1.98s
# 53:	learn: 1530.3647008	total: 2.28s	remaining: 1.94s
# 54:	learn: 1527.6117551	total: 2.32s	remaining: 1.9s
# 55:	learn: 1526.1209237	total: 2.36s	remaining: 1.85s
# 56:	learn: 1523.5947991	total: 2.4s	remaining: 1.81s
# 57:	learn: 1520.8801243	total: 2.44s	remaining: 1.77s
# 58:	learn: 1518.6860236	total: 2.48s	remaining: 1.73s
# 59:	learn: 1516.0812930	total: 2.53s	remaining: 1.69s
# 60:	learn: 1513.5426166	total: 2.57s	remaining: 1.64s
# 61:	learn: 1512.3675406	total: 2.61s	remaining: 1.6s
# 62:	learn: 1509.5015668	total: 2.65s	remaining: 1.56s
# 63:	learn: 1507.4900185	total: 2.69s	remaining: 1.51s
# 64:	learn: 1504.5053589	total: 2.73s	remaining: 1.47s
# 65:	learn: 1501.7322092	total: 2.77s	remaining: 1.43s
# 66:	learn: 1499.7850424	total: 2.82s	remaining: 1.39s
# 67:	learn: 1497.4052999	total: 2.88s	remaining: 1.35s
# 68:	learn: 1495.1125813	total: 2.93s	remaining: 1.31s
# 69:	learn: 1492.9469604	total: 2.97s	remaining: 1.27s
# 70:	learn: 1490.3846669	total: 3.01s	remaining: 1.23s
# 71:	learn: 1488.2656547	total: 3.06s	remaining: 1.19s
# 72:	learn: 1485.9346066	total: 3.1s	remaining: 1.15s
# 73:	learn: 1485.0832626	total: 3.14s	remaining: 1.1s
# 74:	learn: 1484.0917158	total: 3.18s	remaining: 1.06s
# 75:	learn: 1482.3788782	total: 3.23s	remaining: 1.02s
# 76:	learn: 1480.6796961	total: 3.27s	remaining: 977ms
# 77:	learn: 1479.2329800	total: 3.31s	remaining: 935ms
# 78:	learn: 1477.0818410	total: 3.36s	remaining: 893ms
# 79:	learn: 1475.3013177	total: 3.4s	remaining: 850ms
# 80:	learn: 1473.6806774	total: 3.44s	remaining: 808ms
# 81:	learn: 1471.5864822	total: 3.5s	remaining: 769ms
# 82:	learn: 1470.4590238	total: 3.55s	remaining: 726ms
# 83:	learn: 1469.2245222	total: 3.59s	remaining: 685ms
# 84:	learn: 1467.7965924	total: 3.65s	remaining: 644ms
# 85:	learn: 1466.2965497	total: 3.71s	remaining: 604ms
# 86:	learn: 1464.5033032	total: 3.76s	remaining: 561ms
# 87:	learn: 1463.1038182	total: 3.8s	remaining: 518ms
# 88:	learn: 1461.7382134	total: 3.84s	remaining: 475ms
# 89:	learn: 1461.0628241	total: 3.88s	remaining: 431ms
# 90:	learn: 1459.8665266	total: 3.92s	remaining: 388ms
# 91:	learn: 1458.2452983	total: 3.96s	remaining: 345ms
# 92:	learn: 1456.8985981	total: 4s	remaining: 301ms
# 93:	learn: 1455.5894410	total: 4.04s	remaining: 258ms
# 94:	learn: 1453.4446727	total: 4.08s	remaining: 215ms
# 95:	learn: 1452.3551053	total: 4.12s	remaining: 172ms
# 96:	learn: 1450.6848813	total: 4.16s	remaining: 129ms
# 97:	learn: 1449.7957129	total: 4.2s	remaining: 85.7ms
# 98:	learn: 1448.0129211	total: 4.24s	remaining: 42.8ms
# 99:	learn: 1446.5096283	total: 4.28s	remaining: 0us
# 0:	learn: 3326.8300800	total: 38.2ms	remaining: 3.78s
# 1:	learn: 3109.2350497	total: 77.7ms	remaining: 3.81s
# 2:	learn: 2913.7189316	total: 118ms	remaining: 3.83s
# 3:	learn: 2746.4240598	total: 159ms	remaining: 3.81s
# 4:	learn: 2597.1717956	total: 201ms	remaining: 3.81s
# 5:	learn: 2468.3188931	total: 242ms	remaining: 3.79s
# 6:	learn: 2357.0570055	total: 284ms	remaining: 3.77s
# 7:	learn: 2260.3965481	total: 326ms	remaining: 3.75s
# 8:	learn: 2174.4821285	total: 366ms	remaining: 3.7s
# 9:	learn: 2101.7715623	total: 405ms	remaining: 3.65s
# 10:	learn: 2039.9903041	total: 445ms	remaining: 3.6s
# 11:	learn: 1986.8399917	total: 507ms	remaining: 3.72s
# 12:	learn: 1940.6303846	total: 560ms	remaining: 3.75s
# 13:	learn: 1901.7353189	total: 607ms	remaining: 3.73s
# 14:	learn: 1866.8780427	total: 647ms	remaining: 3.67s
# 15:	learn: 1837.2301247	total: 687ms	remaining: 3.6s
# 16:	learn: 1808.1902032	total: 727ms	remaining: 3.55s
# 17:	learn: 1783.8809228	total: 768ms	remaining: 3.5s
# 18:	learn: 1762.5863614	total: 807ms	remaining: 3.44s
# 19:	learn: 1744.3676109	total: 853ms	remaining: 3.41s
# 20:	learn: 1727.6909261	total: 895ms	remaining: 3.37s
# 21:	learn: 1711.3077205	total: 935ms	remaining: 3.31s
# 22:	learn: 1697.9258183	total: 978ms	remaining: 3.27s
# 23:	learn: 1684.4383440	total: 1.02s	remaining: 3.22s
# 24:	learn: 1671.7803265	total: 1.06s	remaining: 3.17s
# 25:	learn: 1661.6089363	total: 1.1s	remaining: 3.12s
# 26:	learn: 1651.7976543	total: 1.13s	remaining: 3.06s
# 27:	learn: 1643.4500491	total: 1.18s	remaining: 3.02s
# 28:	learn: 1634.9899677	total: 1.21s	remaining: 2.97s
# 29:	learn: 1628.3871577	total: 1.26s	remaining: 2.94s
# 30:	learn: 1621.4838863	total: 1.3s	remaining: 2.89s
# 31:	learn: 1615.5385197	total: 1.34s	remaining: 2.85s
# 32:	learn: 1609.3976417	total: 1.38s	remaining: 2.8s
# 33:	learn: 1605.0494815	total: 1.42s	remaining: 2.75s
# 34:	learn: 1600.3674340	total: 1.46s	remaining: 2.71s
# 35:	learn: 1595.2684441	total: 1.5s	remaining: 2.67s
# 36:	learn: 1588.4233222	total: 1.54s	remaining: 2.63s
# 37:	learn: 1584.7205563	total: 1.58s	remaining: 2.58s
# 38:	learn: 1580.8105944	total: 1.62s	remaining: 2.54s
# 39:	learn: 1577.1225574	total: 1.67s	remaining: 2.5s
# 40:	learn: 1573.6354923	total: 1.73s	remaining: 2.49s
# 41:	learn: 1568.4597286	total: 1.77s	remaining: 2.45s
# 42:	learn: 1564.2558060	total: 1.81s	remaining: 2.4s
# 43:	learn: 1560.5190007	total: 1.85s	remaining: 2.35s
# 44:	learn: 1557.4406717	total: 1.89s	remaining: 2.31s
# 45:	learn: 1554.0499039	total: 1.93s	remaining: 2.27s
# 46:	learn: 1550.7353704	total: 1.97s	remaining: 2.23s
# 47:	learn: 1549.0378363	total: 2.02s	remaining: 2.18s
# 48:	learn: 1546.1785322	total: 2.05s	remaining: 2.14s
# 49:	learn: 1543.8781700	total: 2.1s	remaining: 2.1s
# 50:	learn: 1541.6778458	total: 2.13s	remaining: 2.05s
# 51:	learn: 1538.8566896	total: 2.17s	remaining: 2.01s
# 52:	learn: 1536.3166384	total: 2.23s	remaining: 1.98s
# 53:	learn: 1533.8032775	total: 2.27s	remaining: 1.93s
# 54:	learn: 1531.2450477	total: 2.33s	remaining: 1.91s
# 55:	learn: 1529.4152998	total: 2.37s	remaining: 1.86s
# 56:	learn: 1526.5045390	total: 2.42s	remaining: 1.82s
# 57:	learn: 1522.9282304	total: 2.46s	remaining: 1.78s
# 58:	learn: 1520.7737406	total: 2.5s	remaining: 1.74s
# 59:	learn: 1518.8625871	total: 2.55s	remaining: 1.7s
# 60:	learn: 1516.5494095	total: 2.59s	remaining: 1.66s
# 61:	learn: 1514.5518242	total: 2.64s	remaining: 1.62s
# 62:	learn: 1513.0974093	total: 2.68s	remaining: 1.57s
# 63:	learn: 1511.1105573	total: 2.72s	remaining: 1.53s
# 64:	learn: 1508.6244624	total: 2.76s	remaining: 1.49s
# 65:	learn: 1507.2966186	total: 2.8s	remaining: 1.44s
# 66:	learn: 1505.3418142	total: 2.85s	remaining: 1.4s
# 67:	learn: 1502.7838681	total: 2.89s	remaining: 1.36s
# 68:	learn: 1501.1670190	total: 2.93s	remaining: 1.32s
# 69:	learn: 1498.5979764	total: 2.97s	remaining: 1.27s
# 70:	learn: 1495.7118797	total: 3.01s	remaining: 1.23s
# 71:	learn: 1493.8980365	total: 3.06s	remaining: 1.19s
# 72:	learn: 1492.4143183	total: 3.1s	remaining: 1.15s
# 73:	learn: 1490.4226557	total: 3.14s	remaining: 1.1s
# 74:	learn: 1489.1302529	total: 3.18s	remaining: 1.06s
# 75:	learn: 1486.7613774	total: 3.23s	remaining: 1.02s
# 76:	learn: 1484.4386890	total: 3.27s	remaining: 976ms
# 77:	learn: 1483.0873560	total: 3.31s	remaining: 934ms
# 78:	learn: 1481.4347611	total: 3.36s	remaining: 893ms
# 79:	learn: 1480.4357107	total: 3.4s	remaining: 850ms
# 80:	learn: 1478.6906725	total: 3.45s	remaining: 808ms
# 81:	learn: 1477.2339662	total: 3.49s	remaining: 766ms
# 82:	learn: 1474.9055200	total: 3.53s	remaining: 723ms
# 83:	learn: 1473.1403991	total: 3.57s	remaining: 680ms
# 84:	learn: 1471.5859972	total: 3.61s	remaining: 637ms
# 85:	learn: 1469.8886816	total: 3.65s	remaining: 594ms
# 86:	learn: 1468.5610239	total: 3.69s	remaining: 551ms
# 87:	learn: 1467.1785249	total: 3.73s	remaining: 509ms
# 88:	learn: 1465.7039277	total: 3.77s	remaining: 466ms
# 89:	learn: 1464.9380633	total: 3.81s	remaining: 424ms
# 90:	learn: 1463.5440502	total: 3.85s	remaining: 381ms
# 91:	learn: 1461.4792961	total: 3.89s	remaining: 339ms
# 92:	learn: 1460.3009686	total: 3.93s	remaining: 296ms
# 93:	learn: 1459.0493985	total: 3.99s	remaining: 255ms
# 94:	learn: 1457.1149469	total: 4.03s	remaining: 212ms
# 95:	learn: 1455.5269738	total: 4.07s	remaining: 170ms
# 96:	learn: 1454.2380300	total: 4.11s	remaining: 127ms
# 97:	learn: 1453.1245929	total: 4.15s	remaining: 84.7ms
# 98:	learn: 1451.6805836	total: 4.19s	remaining: 42.3ms
# 99:	learn: 1450.3896650	total: 4.23s	remaining: 0us
# 0:	learn: 3322.3374003	total: 44.3ms	remaining: 4.39s
# 1:	learn: 3103.6816855	total: 90.7ms	remaining: 4.45s
# 2:	learn: 2906.6859419	total: 135ms	remaining: 4.37s
# 3:	learn: 2737.4971222	total: 180ms	remaining: 4.32s
# 4:	learn: 2589.4067918	total: 227ms	remaining: 4.31s
# 5:	learn: 2460.6632531	total: 275ms	remaining: 4.31s
# 6:	learn: 2348.3734833	total: 323ms	remaining: 4.29s
# 7:	learn: 2252.7539358	total: 370ms	remaining: 4.26s
# 8:	learn: 2170.4979806	total: 418ms	remaining: 4.22s
# 9:	learn: 2099.6501222	total: 463ms	remaining: 4.17s
# 10:	learn: 2036.2042046	total: 521ms	remaining: 4.21s
# 11:	learn: 1982.9260092	total: 578ms	remaining: 4.24s
# 12:	learn: 1938.4692264	total: 628ms	remaining: 4.2s
# 13:	learn: 1898.4097270	total: 676ms	remaining: 4.15s
# 14:	learn: 1861.2664182	total: 723ms	remaining: 4.09s
# 15:	learn: 1830.7692772	total: 769ms	remaining: 4.04s
# 16:	learn: 1802.0914414	total: 819ms	remaining: 4s
# 17:	learn: 1778.3210754	total: 876ms	remaining: 3.99s
# 18:	learn: 1757.3383780	total: 923ms	remaining: 3.93s
# 19:	learn: 1738.4588385	total: 968ms	remaining: 3.87s
# 20:	learn: 1720.5846084	total: 1.02s	remaining: 3.83s
# 21:	learn: 1706.1972680	total: 1.06s	remaining: 3.77s
# 22:	learn: 1692.7026950	total: 1.11s	remaining: 3.72s
# 23:	learn: 1678.7571610	total: 1.16s	remaining: 3.67s
# 24:	learn: 1667.9866189	total: 1.21s	remaining: 3.62s
# 25:	learn: 1657.5885874	total: 1.26s	remaining: 3.58s
# 26:	learn: 1647.1393892	total: 1.3s	remaining: 3.53s
# 27:	learn: 1636.7644259	total: 1.35s	remaining: 3.48s
# 28:	learn: 1628.7901833	total: 1.4s	remaining: 3.43s
# 29:	learn: 1620.8658632	total: 1.45s	remaining: 3.38s
# 30:	learn: 1615.2247746	total: 1.5s	remaining: 3.33s
# 31:	learn: 1609.4442631	total: 1.54s	remaining: 3.28s
# 32:	learn: 1603.2348954	total: 1.59s	remaining: 3.24s
# 33:	learn: 1598.2466359	total: 1.64s	remaining: 3.19s
# 34:	learn: 1593.2790580	total: 1.7s	remaining: 3.15s
# 35:	learn: 1587.8737176	total: 1.74s	remaining: 3.1s
# 36:	learn: 1582.3680005	total: 1.8s	remaining: 3.06s
# 37:	learn: 1578.3122242	total: 1.86s	remaining: 3.04s
# 38:	learn: 1574.7455573	total: 1.92s	remaining: 3s
# 39:	learn: 1570.6775393	total: 1.97s	remaining: 2.95s
# 40:	learn: 1568.0138293	total: 2.02s	remaining: 2.9s
# 41:	learn: 1563.8747568	total: 2.06s	remaining: 2.85s
# 42:	learn: 1560.6651910	total: 2.11s	remaining: 2.8s
# 43:	learn: 1557.9226967	total: 2.16s	remaining: 2.75s
# 44:	learn: 1554.5799486	total: 2.21s	remaining: 2.7s
# 45:	learn: 1550.7752097	total: 2.26s	remaining: 2.65s
# 46:	learn: 1546.9505009	total: 2.31s	remaining: 2.61s
# 47:	learn: 1544.0551282	total: 2.36s	remaining: 2.56s
# 48:	learn: 1540.7094134	total: 2.42s	remaining: 2.52s
# 49:	learn: 1538.2754570	total: 2.47s	remaining: 2.47s
# 50:	learn: 1536.4834074	total: 2.53s	remaining: 2.43s
# 51:	learn: 1533.4391800	total: 2.58s	remaining: 2.38s
# 52:	learn: 1530.5826849	total: 2.63s	remaining: 2.33s
# 53:	learn: 1527.7176712	total: 2.68s	remaining: 2.28s
# 54:	learn: 1524.8737847	total: 2.73s	remaining: 2.23s
# 55:	learn: 1523.0886721	total: 2.77s	remaining: 2.18s
# 56:	learn: 1519.4620537	total: 2.83s	remaining: 2.13s
# 57:	learn: 1517.1333943	total: 2.88s	remaining: 2.09s
# 58:	learn: 1513.9689709	total: 2.94s	remaining: 2.04s
# 59:	learn: 1512.0975573	total: 3s	remaining: 2s
# 60:	learn: 1510.0582343	total: 3.04s	remaining: 1.95s
# 61:	learn: 1508.3248814	total: 3.09s	remaining: 1.9s
# 62:	learn: 1505.6790477	total: 3.14s	remaining: 1.84s
# 63:	learn: 1503.7719040	total: 3.19s	remaining: 1.79s
# 64:	learn: 1501.4106757	total: 3.23s	remaining: 1.74s
# 65:	learn: 1499.8588565	total: 3.28s	remaining: 1.69s
# 66:	learn: 1498.1617040	total: 3.33s	remaining: 1.64s
# 67:	learn: 1496.3202143	total: 3.38s	remaining: 1.59s
# 68:	learn: 1494.5228641	total: 3.42s	remaining: 1.54s
# 69:	learn: 1492.5308291	total: 3.47s	remaining: 1.49s
# 70:	learn: 1490.7814105	total: 3.52s	remaining: 1.44s
# 71:	learn: 1489.3293733	total: 3.57s	remaining: 1.39s
# 72:	learn: 1488.1059397	total: 3.62s	remaining: 1.34s
# 73:	learn: 1486.4847241	total: 3.67s	remaining: 1.29s
# 74:	learn: 1485.5765528	total: 3.72s	remaining: 1.24s
# 75:	learn: 1483.7836603	total: 3.79s	remaining: 1.2s
# 76:	learn: 1481.6878492	total: 3.86s	remaining: 1.15s
# 77:	learn: 1480.0645793	total: 3.9s	remaining: 1.1s
# 78:	learn: 1478.3816831	total: 3.95s	remaining: 1.05s
# 79:	learn: 1477.1325377	total: 4s	remaining: 999ms
# 80:	learn: 1475.4528976	total: 4.04s	remaining: 948ms
# 81:	learn: 1474.1609271	total: 4.09s	remaining: 899ms
# 82:	learn: 1472.0704839	total: 4.14s	remaining: 848ms
# 83:	learn: 1470.6311086	total: 4.19s	remaining: 799ms
# 84:	learn: 1469.2979866	total: 4.24s	remaining: 749ms
# 85:	learn: 1467.8666398	total: 4.29s	remaining: 699ms
# 86:	learn: 1466.1789590	total: 4.35s	remaining: 651ms
# 87:	learn: 1464.7677711	total: 4.4s	remaining: 600ms
# 88:	learn: 1463.2474293	total: 4.45s	remaining: 550ms
# 89:	learn: 1461.8422621	total: 4.5s	remaining: 500ms
# 90:	learn: 1460.0901420	total: 4.55s	remaining: 450ms
# 91:	learn: 1458.2100691	total: 4.59s	remaining: 400ms
# 92:	learn: 1457.0213095	total: 4.64s	remaining: 349ms
# 93:	learn: 1455.3104866	total: 4.69s	remaining: 299ms
# 94:	learn: 1453.9676881	total: 4.74s	remaining: 249ms
# 95:	learn: 1452.2251218	total: 4.78s	remaining: 199ms
# 96:	learn: 1450.4578482	total: 4.83s	remaining: 149ms
# 97:	learn: 1449.3650380	total: 4.87s	remaining: 99.4ms
# 98:	learn: 1448.4985553	total: 4.92s	remaining: 49.7ms
# 99:	learn: 1446.9629119	total: 4.96s	remaining: 0us
# Search time:366.11789107322693

# %%
pd.set_option('display.max_colwidth', None)
pd.DataFrame(grid_cbr.cv_results_)[
    ['mean_fit_time', 'rank_test_score', 'mean_test_score','params']
].sort_values('rank_test_score')
# Out:
#     mean_fit_time  rank_test_score  mean_test_score  \
# 26       5.000768                1    -2.166672e+06
# 17       3.481949                2    -2.283912e+06
# 25       4.975496                3    -2.415327e+06
# 23       2.882454                4    -2.416661e+06
# 8        3.016938                5    -2.433511e+06
# 14       2.016290                6    -2.552358e+06
# 16       3.685949                7    -2.554198e+06
# 20       2.010267                8    -2.681301e+06
# 5        1.823346                9    -2.727908e+06
# 7        3.012691               10    -2.732607e+06
# 11       1.496732               11    -2.842741e+06
# 22       3.080032               12    -2.843522e+06
# 13       2.133013               13    -3.015155e+06
# 2        1.350207               14    -3.053494e+06
# 4        1.900932               15    -3.233323e+06
# 19       2.031757               16    -3.534231e+06
# 10       1.500037               17    -3.714005e+06
# 1        1.408103               18    -3.974483e+06
# 24       4.933059               19    -4.550236e+06
# 15       3.991543               20    -4.727932e+06
# 6        3.301346               21    -5.033948e+06
# 21       3.310660               22    -6.885458e+06
# 12       2.156967               23    -7.053315e+06
# 3        1.848499               24    -7.322576e+06
# 18       1.992907               25    -8.604256e+06
# 9        1.986263               26    -8.735312e+06
# 0        1.400413               27    -8.941469e+06
#
#                                                      params
# 26   {'depth': 10, 'iterations': 100, 'learning_rate': 0.1}
# 17    {'depth': 8, 'iterations': 100, 'learning_rate': 0.1}
# 25  {'depth': 10, 'iterations': 100, 'learning_rate': 0.05}
# 23    {'depth': 10, 'iterations': 50, 'learning_rate': 0.1}
# 8     {'depth': 6, 'iterations': 100, 'learning_rate': 0.1}
# 14     {'depth': 8, 'iterations': 50, 'learning_rate': 0.1}
# 16   {'depth': 8, 'iterations': 100, 'learning_rate': 0.05}
# 20    {'depth': 10, 'iterations': 30, 'learning_rate': 0.1}
# 5      {'depth': 6, 'iterations': 50, 'learning_rate': 0.1}
# 7    {'depth': 6, 'iterations': 100, 'learning_rate': 0.05}
# 11     {'depth': 8, 'iterations': 30, 'learning_rate': 0.1}
# 22   {'depth': 10, 'iterations': 50, 'learning_rate': 0.05}
# 13    {'depth': 8, 'iterations': 50, 'learning_rate': 0.05}
# 2      {'depth': 6, 'iterations': 30, 'learning_rate': 0.1}
# 4     {'depth': 6, 'iterations': 50, 'learning_rate': 0.05}
# 19   {'depth': 10, 'iterations': 30, 'learning_rate': 0.05}
# 10    {'depth': 8, 'iterations': 30, 'learning_rate': 0.05}
# 1     {'depth': 6, 'iterations': 30, 'learning_rate': 0.05}
# 24  {'depth': 10, 'iterations': 100, 'learning_rate': 0.01}
# 15   {'depth': 8, 'iterations': 100, 'learning_rate': 0.01}
# 6    {'depth': 6, 'iterations': 100, 'learning_rate': 0.01}
# 21   {'depth': 10, 'iterations': 50, 'learning_rate': 0.01}
# 12    {'depth': 8, 'iterations': 50, 'learning_rate': 0.01}
# 3     {'depth': 6, 'iterations': 50, 'learning_rate': 0.01}
# 18   {'depth': 10, 'iterations': 30, 'learning_rate': 0.01}
# 9     {'depth': 8, 'iterations': 30, 'learning_rate': 0.01}
# 0     {'depth': 6, 'iterations': 30, 'learning_rate': 0.01}

# %%
grid_cbr_rmse = (grid_cbr.best_score_ * -1) ** .5
grid_cbr_rmse
# Out:
# 1471.961921582955

# %%
# %%time

predict_cbr_gs = grid_cbr.predict(X_train_total)
# Out:
# CPU times: user 82.9 ms, sys: 3.96 ms, total: 86.9 ms
# Wall time: 97.4 ms

# %% [markdown]
# Подобрал лучшие гиперпараметры через GridSearchCV.Обучил CatBoostRegressor на закодированных данных,вывел время на данные операции и лучший RMSE для данной модели равен 1472

# %% [markdown]
# ### Обучение LightGBMRegressor

# %%
start = time.time()

model_lgbmr = LGBMRegressor(learning_rate=.5, num_leaves=10, random_state=RANDOM_STATE)
score_lgbmr = cross_val_score(model_lgbmr, X_train_total, y_train, scoring='neg_mean_squared_error', cv=5)
score_lgbmr = round(np.mean(-score_lgbmr)**0.5, 2)
print(f"Среднее значение RMSE: {score_lgbmr:.2f}")

lgbmr_search_time = time.time() - start
print(f'Search time:{round(lgbmr_search_time, 2)}')
# Out:
# Среднее значение RMSE: 1434.90
# Search time:147.96

# %%
# %%time

model_lgbmr.fit(X_train_total, y_train)
# Out:
# CPU times: user 3.53 s, sys: 43.1 ms, total: 3.57 s
# Wall time: 3.6 s
# LGBMRegressor(learning_rate=0.5, num_leaves=10, random_state=37)

# %%
# %%time

predict_lgbmr = model_lgbmr.predict(X_train_total)
# Out:
# CPU times: user 877 ms, sys: 24 ms, total: 901 ms
# Wall time: 901 ms

# %% [markdown]
# Обучил LightGBMRegressor,в ручную подобрал гиперпараметры,вывел время на данные операции и cреднее значение RMSE: 1434.90

# %% [markdown]
# ## Анализ моделей

# %%
result = pd.DataFrame(
    [['1.21 s', '19 ms', score_lr],
    ['5.05 s', '351 ms', score_cbr],
    ['4.9 s', '109 ms', grid_cbr_rmse],
    ['4.8 s', '987 ms', score_lgbmr]],
    index=['Linear Regression', 'CatBoostRegressor', 'CatBoostRegressor c OHE, OE', 'LGBMRegressor'],
    columns=['fit_time', 'predict_time', 'RMSE']
)
result
# Out:
#                             fit_time predict_time         RMSE
# Linear Regression             1.21 s        19 ms  2208.980000
# CatBoostRegressor             5.05 s       351 ms  1449.440000
# CatBoostRegressor c OHE, OE    4.9 s       109 ms  1471.961922
# LGBMRegressor                  4.8 s       987 ms  1434.900000

# %% [markdown]
# Таблица сравнения моделей, вывел сравнительное время обучения,предсказания и метрику RMSE, лучшей моделю по метрике и времени обучения оказалась LGBMRegressor с гиперпараметрами learning_rate=0.5, num_leaves=10.

# %%
# %%time
predict_test = model_lgbmr.predict(X_test_total)
# Out:
# CPU times: user 314 ms, sys: 2.76 ms, total: 317 ms
# Wall time: 244 ms

# %%
print(mean_squared_error(y_test, predict_test) ** .5)
# Out:
# 1451.5632052738397

# %% [markdown]
# RMSE лучшей модели на тестовых данных получился 1451.6, показатель приближен к среднему валидационному,значит качество данных хорошее.

# %% [markdown]
# ## Итоговый вывод

# %% [markdown]
# По итогам проделанной работы было сделанно следующее:
# ### Открыл файл с данными и изучил иформацию
# - Загрузил данные
# - Вывел первые строки,изучил общую информацию.Данные представлены в 15 столбцах и 354369 строках
# ### Предобработал данные
# - Обнаружил 4 дубликата,удалил их
# - Названия столбцов в датафреймах перевел в змеиный стиль
# - Изучил уникальные значения во всех столбцах
# - Заменил пропуски в столбцах на заглушки,если удалить строки с пропуском будет большая потеря данных
# ### Провел исследовательский анализ данных
# - Вывел и изучил данные как категориальные, так и числовые
# - Вывел основные статистические характеристики данных по каждому числовому признаку
# - В целевом признаке убрал дынные где слишком низкая цена до 200 и выбросы более 14600,как ориентир были взяты 0,05 и 0,95 квантиль
# ### Провел корреляционный анализ
# - Провел корреляционный анализ, видим зависимость у столбцов и бренд,так же у модели и типа автомобильного кузова,бренда и типа автомобильного кузова,год регистрации автомобиля и цены,моделя и цены,модели с годом регистрации автомобиля и типом коробки передач.На основе этой таблицы удалил признак *brand*,так как он сильно коррелирует с другими
# ### Обучил модели
# - Разделил данные на тестовые и тренировочные, подготовил данные для кодировки OHE  и столбец *model* OE, стандартизации StandardScaler(),проверил разделении,все соответствует
# - Обучил модели Linear Regression, CatBoostRegressor, CatBoostRegressor c подбором лучших гиперпараметров через GridSearchCV, и  LGBMRegressor
# - Проверил время обучения и предсказания на всех моделях и метрику RMSE
# - Лучшей моделю по метрике и времени обучения оказалась LGBMRegressor с гиперпараметрами learning_rate=0.5, num_leaves=10, время затраченное на обучение вышло в 4.9 s, на предсказание 1 s и средняя метрика RMSE=1434.9
# ### Провел анализ моделей
# - Вывел сравнительную таблицу
# - Предсказал на тестовых данных лучшую модель,RMSE лучшей модели на тестовых данных получился 1451.6, показатель приближен к тренировочным,значит качество данных хорошее
#
# Лучшая модель для определения стоимости, это LGBMRegressor, время обучения и среднии показатель RMSE самый лучший.

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Выполнена загрузка и подготовка данных
# - [x]  Выполнено обучение моделей
# - [x]  Есть анализ скорости работы и качества моделей
